# %%
import json
import pandas as pd
import numpy as np

# %%
# The path where the json test file is stored (it's in the same directory so leaving it an empty string)
file_dir = "Data/"


# Load the filesinto a list of Dictionaries NOT RIGHT TO JSON
# Using the with statement, open the Wikipedia JSON file to be 
# read into the variable file, and use json.load() to save the 
# data to a new variable.
with open(f'{file_dir}wikipedia-movies.json', mode='r') as file:
    wiki_movies_raw = json.load(file)

# see how many records are pulled in 
len(wiki_movies_raw)
# Out:
# 7311

# %%
# To see the first five records in the list of dictionaries
# we use this syntax
wiki_movies_raw[:5]
# Out:
# [{'url': 'https://en.wikipedia.org/wiki/The_Adventures_of_Ford_Fairlane',
#   'year': 1990,
#   'imdb_link': 'https://www.imdb.com/title/tt0098987/',
#   'title': 'The Adventures of Ford Fairlane',
#   'Directed by': 'Renny Harlin',
#   'Produced by': ['Steve Perry', 'Joel Silver'],
#   'Screenplay by': ['David Arnott', 'James Cappe', 'Daniel Waters'],
#   'Story by': ['David Arnott', 'James Cappe'],
#   'Based on': ['Characters', 'by Rex Weiner'],
#   'Starring': ['Andrew Dice Clay',
#    'Wayne Newton',
#    'Priscilla Presley',
#    'Lauren Holly',
#    'Morris Day',
#    'Robert Englund',
#    "Ed O'Neill"],
#   'Narrated by': 'Andrew "Dice" Clay',
#   'Music by': ['Cliff Eidelman', 'Yello'],
#   'Cinematography': 'Oliver Wood',
#   'Edited by': 'Michael Tronick',
#   'Productioncompany ': 'Silver Pictures',
#   'Distributed by': '20th Century Fox',
#   'Release date': ['July 11, 1990', '(', '1990-07-11', ')'],
#   'Running time': '102 minutes',
#   'Country': 'United States',
#   'Language': 'English',
#   'Budget': '$20 million',
#   'Box office': '$21.4 million'},
#  {'url': 'https://en.wikipedia.org/wiki/After_Dark,_My_Sweet',
#   'year': 1990,
#   'imdb_link': 'https://www.imdb.com/title/tt0098994/',
#   'title': 'After Dark, My Sweet',
#   'Directed by': 'James Foley',
#   'Produced by': ['Ric Kidney', 'Robert Redlin'],
#   'Screenplay by': ['James Foley', 'Robert Redlin'],
#   'Based on': ['the novel', 'After Dark, My Sweet', 'by', 'Jim Thompson'],
#   'Starring': ['Jason Patric',
#    'Rachel Ward',
#    'Bruce Dern',
#    'George Dickerson'],
#   'Music by': 'Maurice Jarre',
#   'Cinematography': 'Mark Plummer',
#   'Edited by': 'Howard E. Smith',
#   'Productioncompany ': 'Avenue Pictures',
#   'Distributed by': 'Avenue Pictures',
#   'Release date': ['May 17, 1990',
#    '(',
#    '1990-05-17',
#    ')',
#    '(Cannes Film Market)',
#    'August 24, 1990',
#    '(',
#    '1990-08-24',
#    ')',
#    '(United States)'],
#   'Running time': '114 minutes',
#   'Country': 'United States',
#   'Language': 'English',
#   'Budget': '$6 million',
#   'Box office': '$2.7 million'},
#  {'url': 'https://en.wikipedia.org/wiki/Air_America_(film)',
#   'year': 1990,
#   'imdb_link': 'https://www.imdb.com/title/tt0099005/',
#   'title': 'Air America',
#   'Directed by': 'Roger Spottiswoode',
#   'Produced by': 'Daniel Melnick',
#   'Screenplay by': ['John Eskow', 'Richard Rush'],
#   'Based on': ['Air America', 'by', 'Christopher Robbins'],
#   'Starring': ['Mel Gibson',
#    'Robert Downey Jr.',
#    'Nancy Travis',
#    'David Marshall Grant',
#    'Lane Smith'],
#   'Music by': 'Charles Gross',
#   'Cinematography': 'Roger Deakins',
#   'Edited by': ['John Bloom', 'Lois Freeman-Fox'],
#   'Productioncompany ': ['Carolco Pictures', 'IndieProd Company'],
#   'Distributed by': 'TriStar Pictures',
#   'Release date': ['August 10, 1990', '(', '1990-08-10', ')'],
#   'Running time': '113 minutes',
#   'Country': 'United States',
#   'Language': ['English', 'Lao'],
#   'Budget': '$35 million',
#   'Box office': '$57,718,089'},
#  {'url': 'https://en.wikipedia.org/wiki/Alice_(1990_film)',
#   'year': 1990,
#   'imdb_link': 'https://www.imdb.com/title/tt0099012/',
#   'title': 'Alice',
#   'Directed by': 'Woody Allen',
#   'Produced by': 'Robert Greenhut',
#   'Written by': 'Woody Allen',
#   'Starring': ['Alec Baldwin',
#    'Blythe Danner',
#    'Judy Davis',
#    'Mia Farrow',
#    'William Hurt',
#    'Keye Luke',
#    'Joe Mantegna',
#    'Bernadette Peters'],
#   'Cinematography': 'Carlo Di Palma',
#   'Edited by': 'Susan E. Morse',
#   'Distributed by': 'Orion Pictures',
#   'Release date': ['December 25, 1990', '(', '1990-12-25', ')'],
#   'Running time': '106 minutes',
#   'Country': 'United States',
#   'Language': 'English',
#   'Budget': '$12 million',
#   'Box office': '$7,331,647'},
#  {'url': 'https://en.wikipedia.org/wiki/Almost_an_Angel',
#   'year': 1990,
#   'imdb_link': 'https://www.imdb.com/title/tt0099018/',
#   'title': 'Almost an Angel',
#   'Directed by': 'John Cornell',
#   'Produced by': 'John Cornell',
#   'Written by': 'Paul Hogan',
#   'Starring': ['Paul Hogan', 'Elias Koteas', 'Linda Kozlowski'],
#   'Music by': 'Maurice Jarre',
#   'Cinematography': 'Russell Boyd',
#   'Edited by': 'David Stiven',
#   'Distributed by': 'Paramount Pictures',
#   'Release date': 'December 19, 1990',
#   'Running time': '95 minutes',
#   'Country': 'US',
#   'Language': 'English',
#   'Budget': '$25 million',
#   'Box office': '$6,939,946 (USA)'}]

# %%
# To see the LAST five records in the list of dictionaries
# we use this syntax
wiki_movies_raw[-5:]
# Out:
# [{'url': 'https://en.wikipedia.org/wiki/Holmes_%26_Watson',
#   'year': 2018,
#   'imdb_link': 'https://www.imdb.com/title/tt1255919/',
#   'title': 'Holmes & Watson',
#   'Directed by': 'Etan Cohen',
#   'Produced by': ['Will Ferrell',
#    'Adam McKay',
#    'Jimmy Miller',
#    'Clayton Townsend'],
#   'Screenplay by': 'Etan Cohen',
#   'Based on': ['Sherlock Holmes',
#    'and',
#    'Dr. Watson',
#    'by',
#    'Sir Arthur Conan Doyle'],
#   'Starring': ['Will Ferrell',
#    'John C. Reilly',
#    'Rebecca Hall',
#    'Rob Brydon',
#    'Steve Coogan',
#    'Ralph Fiennes'],
#   'Music by': 'Mark Mothersbaugh',
#   'Cinematography': 'Oliver Wood',
#   'Edited by': 'Dean Zimmerman',
#   'Productioncompanies ': ['Columbia Pictures',
#    'Gary Sanchez Productions',
#    'Mosaic Media Group',
#    'Mimran Schur Pictures'],
#   'Distributed by': 'Sony Pictures Releasing',
#   'Release date': ['December 25, 2018',
#    '(',
#    '2018-12-25',
#    ')',
#    '(United States)'],
#   'Running time': '90 minutes',
#   'Country': 'United States',
#   'Language': 'English',
#   'Budget': '$42 million',
#   'Box office': '$41.9 million'},
#  {'url': 'https://en.wikipedia.org/wiki/Vice_(2018_film)',
#   'year': 2018,
#   'imdb_link': 'https://www.imdb.com/title/tt6266538/',
#   'title': 'Vice',
#   'Directed by': 'Adam McKay',
#   'Produced by': ['Brad Pitt',
#    'Dede Gardner',
#    'Jeremy Kleiner',
#    'Kevin J. Messick',
#    'Will Ferrell',
#    'Adam McKay'],
#   'Written by': 'Adam McKay',
#   'Starring': ['Christian Bale',
#    'Amy Adams',
#    'Steve Carell',
#    'Sam Rockwell',
#    'Tyler Perry',
#    'Alison Pill',
#    'Lily Rabe',
#    'Jesse Plemons'],
#   'Music by': 'Nicholas Britell',
#   'Cinematography': 'Greig Fraser',
#   'Edited by': 'Hank Corwin',
#   'Productioncompany ': ['Plan B Entertainment',
#    'Gary Sanchez Productions',
#    'Annapurna Pictures'],
#   'Distributed by': 'Mirror Releasing',
#   'Release date': ['December 11, 2018',
#    '(',
#    '2018-12-11',
#    ')',
#    '(',
#    'Samuel Goldwyn Theater',
#    ')',
#    'December 25, 2018',
#    '(',
#    '2018-12-25',
#    ')',
#    '(United States)'],
#   'Running time': '132 minutes',
#   'Country': 'United States',
#   'Language': 'English',
#   'Budget': '$60 million',
#   'Box office': '$76.1 million'},
#  {'url': 'https://en.wikipedia.org/wiki/On_the_Basis_of_Sex',
#   'year': 2018,
#   'imdb_link': 'https://www.imdb.com/title/tt4669788/',
#   'title': 'On the Basis of Sex',
#   'Directed by': 'Mimi Leder',
#   'Produced by': 'Robert W. Cort',
#   'Written by': 'Daniel Stiepleman',
#   'Starring': ['Felicity Jones',
#    'Armie Hammer',
#    'Justin Theroux',
#    'Sam Waterston',
#    'Kathy Bates'],
#   'Music by': 'Mychael Danna',
#   'Cinematography': 'Michael Grady',
#   'Edited by': 'Michelle Tesoro',
#   'Productioncompanies ': ['Focus Features',
#    '[1]',
#    'Participant Media',
#    '[1]',
#    'Robert Cort Productions',
#    '[1]',
#    'Alibaba Pictures',
#    '[2]'],
#   'Distributed by': 'Focus Features',
#   'Release date': ['November 8, 2018',
#    '(',
#    '2018-11-08',
#    ')',
#    '(',
#    'AFI Fest',
#    ')',
#    'December 25, 2018',
#    '(',
#    '2018-12-25',
#    ')',
#    '(United States)'],
#   'Running time': '120 minutes',
#   'Country': 'United States',
#   'Language': 'English',
#   'Budget': '$20 million',
#   'Box office': '$38.4 million'},
#  {'url': 'https://en.wikipedia.org/wiki/Destroyer_(2018_film)',
#   'year': 2018,
#   'imdb_link': 'https://www.imdb.com/title/tt7137380/',
#   'title': 'Destroyer',
#   'Directed by': 'Karyn Kusama',
#   'Produced by': ['Fred Berger', 'Phil Hay', 'Matt Manfredi'],
#   'Written by': ['Phil Hay', 'Matt Manfredi'],
#   'Starring': ['Nicole Kidman',
#    'Sebastian Stan',
#    'Toby Kebbell',
#    'Tatiana Maslany',
#    'Bradley Whitford',
#    'Jade Pettyjohn',
#    'Scoot McNairy'],
#   'Music by': 'Theodore Shapiro',
#   'Cinematography': 'Julie Kirkwood',
#   'Edited by': 'Plummy Tucker',
#   'Productioncompany ': ['30West',
#    'Automatik Entertainment',
#    'Annapurna Pictures'],
#   'Distributed by': 'Mirror Releasing',
#   'Release date': ['August 31, 2018',
#    '(',
#    '2018-08-31',
#    ')',
#    '(',
#    'Telluride',
#    ')',
#    'December 25, 2018',
#    '(',
#    '2018-12-25',
#    ')',
#    '(United States)'],
#   'Running time': '123 minutes',
#   'Country': 'United States',
#   'Language': 'English',
#   'Budget': '$9 million',
#   'Box office': '$5.5 million'},
#  {'url': 'https://en.wikipedia.org/wiki/Black_Mirror:_Bandersnatch',
#   'year': 2018,
#   'imdb_link': 'https://www.imdb.com/title/tt9495224/',
#   'title': 'Bandersnatch',
#   'Directed by': 'David Slade',
#   'Produced by': 'Russell McLean',
#   'Written by': 'Charlie Brooker',
#   'Starring': ['Fionn Whitehead',
#    'Will Poulter',
#    'Craig Parkinson',
#    'Alice Lowe',
#    'Asim Chaudhry'],
#   'Music by': 'Brian Reitzell',
#   'Cinematography': ['Aaron Morton', 'Jake Polonsky'],
#   'Edited by': 'Tony Kearns',
#   'Productioncompany ': ['House of Tomorrow', 'Netflix'],
#   'Distributed by': 'Netflix',
#   'Release date': ['28 December 2018', '(', '2018-12-28', ')'],
#   'Running time': 'Variable; 90 minutes for default path',
#   'Country': 'United Kingdom',
#   'Language': 'English'}]

# %%
# Look at Dictionary records in the middle 
wiki_movies_raw[3600:3605]
# Out:
# [{'url': 'https://en.wikipedia.org/wiki/Benji:_Off_the_Leash!',
#   'year': 2004,
#   'imdb_link': 'https://www.imdb.com/title/tt0315273/',
#   'title': 'Benji: Off the Leash!',
#   'Directed by': 'Joe Camp',
#   'Written by': 'Joe Camp',
#   'Starring': ['Benji', 'Nick Whitaker', 'Shaggy', 'Gypsy the Cockatoo'],
#   'Music by': 'Antonio di Lorenzo',
#   'Productioncompany ': 'Mulberry Square Productions',
#   'Distributed by': 'Mulberry Square Productions',
#   'Release date': ['March 26, 2004', '(', '2004-03-26', ')'],
#   'Running time': '97 min',
#   'Country': 'United States',
#   'Language': 'English',
#   'Box office': '$3,817,362'},
#  {'url': 'https://en.wikipedia.org/wiki/The_Best_Thief_in_the_World',
#   'year': 2004,
#   'imdb_link': 'https://www.imdb.com/title/tt0389796/',
#   'title': 'The Best Thief in the World',
#   'Directed by': 'Jacob Kornbluth',
#   'Produced by': ['Tim Perrell', 'Nicola Usborne'],
#   'Written by': 'Jacob Kornbluth',
#   'Starring': ['Marc Rozendaal',
#    'Michael Silverman',
#    'David Warshofsky',
#    'Audra McDonald',
#    'Lois Smith'],
#   'Music by': ['Prince Paul', 'and', 'Don Newkirk'],
#   'Cinematography': 'Ben Kutchins',
#   'Edited by': 'Stephanie Sterner',
#   'Distributed by': 'Showtime Networks',
#   'Release date': ['January 16, 2004', '(', '2004-01-16', ')'],
#   'Running time': '93 minutes',
#   'Country': 'United States',
#   'Language': 'English'},
#  {'url': 'https://en.wikipedia.org/wiki/Beyond_the_Sea_(2004_film)',
#   'year': 2004,
#   'imdb_link': 'https://www.imdb.com/title/tt0363473/',
#   'title': 'Beyond the Sea',
#   'Directed by': 'Kevin Spacey',
#   'Produced by': ['Kevin Spacey',
#    'Phillip Barry',
#    'Dana Brunetti',
#    'Arthur Friedman',
#    'Jan Fantl',
#    'Andy Paterson'],
#   'Written by': ['Lewis Colick', 'Kevin Spacey'],
#   'Starring': ['Kevin Spacey', 'Kate Bosworth', 'Bob Hoskins', 'John Goodman'],
#   'Music by': 'Bobby Darin',
#   'Cinematography': 'Eduardo Serra',
#   'Edited by': 'Trevor Waite',
#   'Productioncompany ': 'Trigger Street Productions',
#   'Distributed by': ['Lionsgate Films',
#    '(USA)',
#    'Entertainment Film Distributors',
#    '(UK)',
#    'GAGA',
#    '(Japan)',
#    'Maple Pictures',
#    '(Canada)'],
#   'Release date': ['December 17, 2004', '(', '2004-12-17', ')'],
#   'Running time': '118 minutes',
#   'Country': 'United States',
#   'Language': 'English',
#   'Budget': '$25 million',
#   'Box office': '$8.4 million'},
#  {'url': 'https://en.wikipedia.org/wiki/The_Big_Bounce_(2004_film)',
#   'year': 2004,
#   'imdb_link': 'https://www.imdb.com/title/tt0315824/',
#   'title': 'The Big Bounce',
#   'Directed by': 'George Armitage',
#   'Produced by': ['George Armitage', 'Steve Bing'],
#   'Screenplay by': 'Sebastian Gutierrez',
#   'Based on': ['The Big Bounce', 'by', 'Elmore Leonard'],
#   'Starring': ['Owen Wilson',
#    'Charlie Sheen',
#    'Morgan Freeman',
#    'Sara Foster',
#    'Gary Sinise'],
#   'Music by': 'George S. Clinton',
#   'Cinematography': 'Jeffrey L. Kimball',
#   'Edited by': 'Barry Malkin',
#   'Productioncompany ': 'Shangri-La Entertainment',
#   'Distributed by': 'Warner Bros. Pictures',
#   'Release date': ['January 30, 2004', '(', '2004-01-30', ')'],
#   'Running time': '88 minutes',
#   'Language': 'English',
#   'Budget': '$50 million',
#   'Box office': '$6.8 million'},
#  {'url': 'https://en.wikipedia.org/wiki/Birth_(film)',
#   'year': 2004,
#   'imdb_link': 'https://www.imdb.com/title/tt0337876/',
#   'title': 'Birth',
#   'Directed by': 'Jonathan Glazer',
#   'Produced by': ['Lizie Gower', 'Nick Morris', 'Jean-Louis Piel'],
#   'Written by': ['Jean-Claude Carrière', 'Milo Addica', 'Jonathan Glazer'],
#   'Starring': ['Nicole Kidman',
#    'Cameron Bright',
#    'Danny Huston',
#    'Lauren Bacall'],
#   'Music by': 'Alexandre Desplat',
#   'Cinematography': 'Harris Savides',
#   'Edited by': ['Sam Sneade', 'Claus Wehlisch'],
#   'Distributed by': 'New Line Cinema',
#   'Release date': ['November 8, 2004', '(', '2004-11-08', ')'],
#   'Running time': '96 minutes',
#   'Country': 'United States',
#   'Language': 'English',
#   'Budget': '$20 million',
#   'Box office': '$23.9 million'}]

# %%
# Since the Kaggle data is already in flat-file formats, we'll just pull them into 
# Pandas DataFrames directly with the following code.
kaggle_metadata = pd.read_csv(f'{file_dir}movies_metadata.csv', low_memory=False)
ratings = pd.read_csv(f'{file_dir}ratings.csv')

# %%
# Inspect the header rows
ratings.head()
# Out:
#    userId  movieId  rating   timestamp
# 0       1      110     1.0  1425941529
# 1       1      147     4.5  1425942435
# 2       1      858     5.0  1425941523
# 3       1     1221     5.0  1425941546
# 4       1     1246     5.0  1425941556

# %%
# Inspect the end rows
ratings.tail()
# Out:
#           userId  movieId  rating   timestamp
# 26024284  270896    58559     5.0  1257031564
# 26024285  270896    60069     5.0  1257032032
# 26024286  270896    63082     4.5  1257031764
# 26024287  270896    64957     4.5  1257033990
# 26024288  270896    71878     2.0  1257031858

# %%
# #Errors can still occur in the middle of the file, 
# so the best practice is to sample a handful of rows randomly 
# using the sample() method. 
# For a DataFrame called df, df.sample(n=5) will show five random 
# rows from the dataset
ratings.sample(5)
# Out:
#           userId  movieId  rating   timestamp
# 6786509    70028    90376     4.5  1330882171
# 19243923  199828     2525     2.5  1097801102
# 16270814  169076     1680     3.0   954028763
# 12134660  125820     2706     3.0   938766157
# 16842835  175031      527     5.0   851220170

# %%
ratings.dtypes
# Out:
# userId         int64
# movieId        int64
# rating       float64
# timestamp      int64
# dtype: object

# %%
# Convert list of dictionaries to a data frame
wiki_movies_df = pd.DataFrame(wiki_movies_raw)

# %%
wiki_movies_df.head()
# Out:
#                                                  url    year  \
# 0  https://en.wikipedia.org/wiki/The_Adventures_o...  1990.0
# 1  https://en.wikipedia.org/wiki/After_Dark,_My_S...  1990.0
# 2   https://en.wikipedia.org/wiki/Air_America_(film)  1990.0
# 3    https://en.wikipedia.org/wiki/Alice_(1990_film)  1990.0
# 4      https://en.wikipedia.org/wiki/Almost_an_Angel  1990.0
#
#                                imdb_link                            title  \
# 0  https://www.imdb.com/title/tt0098987/  The Adventures of Ford Fairlane
# 1  https://www.imdb.com/title/tt0098994/             After Dark, My Sweet
# 2  https://www.imdb.com/title/tt0099005/                      Air America
# 3  https://www.imdb.com/title/tt0099012/                            Alice
# 4  https://www.imdb.com/title/tt0099018/                  Almost an Angel
#
#           Directed by                  Produced by  \
# 0        Renny Harlin   [Steve Perry, Joel Silver]
# 1         James Foley  [Ric Kidney, Robert Redlin]
# 2  Roger Spottiswoode               Daniel Melnick
# 3         Woody Allen              Robert Greenhut
# 4        John Cornell                 John Cornell
#
#                                 Screenplay by                     Story by  \
# 0  [David Arnott, James Cappe, Daniel Waters]  [David Arnott, James Cappe]
# 1                [James Foley, Robert Redlin]                          NaN
# 2                  [John Eskow, Richard Rush]                          NaN
# 3                                         NaN                          NaN
# 4                                         NaN                          NaN
#
#                                             Based on  \
# 0                        [Characters, by Rex Weiner]
# 1  [the novel, After Dark, My Sweet, by, Jim Thom...
# 2             [Air America, by, Christopher Robbins]
# 3                                                NaN
# 4                                                NaN
#
#                                             Starring         Narrated by  \
# 0  [Andrew Dice Clay, Wayne Newton, Priscilla Pre...  Andrew "Dice" Clay
# 1  [Jason Patric, Rachel Ward, Bruce Dern, George...                 NaN
# 2  [Mel Gibson, Robert Downey Jr., Nancy Travis, ...                 NaN
# 3  [Alec Baldwin, Blythe Danner, Judy Davis, Mia ...                 NaN
# 4        [Paul Hogan, Elias Koteas, Linda Kozlowski]                 NaN
#
#                   Music by  Cinematography                       Edited by  \
# 0  [Cliff Eidelman, Yello]     Oliver Wood                 Michael Tronick
# 1            Maurice Jarre    Mark Plummer                 Howard E. Smith
# 2            Charles Gross   Roger Deakins  [John Bloom, Lois Freeman-Fox]
# 3                      NaN  Carlo Di Palma                  Susan E. Morse
# 4            Maurice Jarre    Russell Boyd                    David Stiven
#
#                       Productioncompany       Distributed by  \
# 0                        Silver Pictures    20th Century Fox
# 1                        Avenue Pictures     Avenue Pictures
# 2  [Carolco Pictures, IndieProd Company]    TriStar Pictures
# 3                                    NaN      Orion Pictures
# 4                                    NaN  Paramount Pictures
#
#                                         Release date Running time  \
# 0                  [July 11, 1990, (, 1990-07-11, )]  102 minutes
# 1  [May 17, 1990, (, 1990-05-17, ), (Cannes Film ...  114 minutes
# 2                [August 10, 1990, (, 1990-08-10, )]  113 minutes
# 3              [December 25, 1990, (, 1990-12-25, )]  106 minutes
# 4                                  December 19, 1990   95 minutes
#
#          Country        Language       Budget        Box office   Written by  \
# 0  United States         English  $20 million     $21.4 million          NaN
# 1  United States         English   $6 million      $2.7 million          NaN
# 2  United States  [English, Lao]  $35 million       $57,718,089          NaN
# 3  United States         English  $12 million        $7,331,647  Woody Allen
# 4             US         English  $25 million  $6,939,946 (USA)   Paul Hogan
#
#   Genre Theme music composer Country of origin Original language(s)  \
# 0   NaN                  NaN               NaN                  NaN
# 1   NaN                  NaN               NaN                  NaN
# 2   NaN                  NaN               NaN                  NaN
# 3   NaN                  NaN               NaN                  NaN
# 4   NaN                  NaN               NaN                  NaN
#
#   Producer(s) Editor(s) Production company(s) Original network  \
# 0         NaN       NaN                   NaN              NaN
# 1         NaN       NaN                   NaN              NaN
# 2         NaN       NaN                   NaN              NaN
# 3         NaN       NaN                   NaN              NaN
# 4         NaN       NaN                   NaN              NaN
#
#   Original release Productioncompanies  Executive producer(s)  \
# 0              NaN                  NaN                   NaN
# 1              NaN                  NaN                   NaN
# 2              NaN                  NaN                   NaN
# 3              NaN                  NaN                   NaN
# 4              NaN                  NaN                   NaN
#
#   Production location(s) Distributor Picture format Audio format Voices of  \
# 0                    NaN         NaN            NaN          NaN       NaN
# 1                    NaN         NaN            NaN          NaN       NaN
# 2                    NaN         NaN            NaN          NaN       NaN
# 3                    NaN         NaN            NaN          NaN       NaN
# 4                    NaN         NaN            NaN          NaN       NaN
#
#   Followed by Composer(s) Created by Also known as Opening theme  \
# 0         NaN         NaN        NaN           NaN           NaN
# 1         NaN         NaN        NaN           NaN           NaN
# 2         NaN         NaN        NaN           NaN           NaN
# 3         NaN         NaN        NaN           NaN           NaN
# 4         NaN         NaN        NaN           NaN           NaN
#
#   No. of episodes Preceded by Author Publisher Publication date Media type  \
# 0             NaN         NaN    NaN       NaN              NaN        NaN
# 1             NaN         NaN    NaN       NaN              NaN        NaN
# 2             NaN         NaN    NaN       NaN              NaN        NaN
# 3             NaN         NaN    NaN       NaN              NaN        NaN
# 4             NaN         NaN    NaN       NaN              NaN        NaN
#
#   Pages ISBN OCLC LC Class Cover artist Series Set in Adaptation by  \
# 0   NaN  NaN  NaN      NaN          NaN    NaN    NaN           NaN
# 1   NaN  NaN  NaN      NaN          NaN    NaN    NaN           NaN
# 2   NaN  NaN  NaN      NaN          NaN    NaN    NaN           NaN
# 3   NaN  NaN  NaN      NaN          NaN    NaN    NaN           NaN
# 4   NaN  NaN  NaN      NaN          NaN    NaN    NaN           NaN
#
#   Suggested by Biographical data Born Died Resting place Occupation  \
# 0          NaN               NaN  NaN  NaN           NaN        NaN
# 1          NaN               NaN  NaN  NaN           NaN        NaN
# 2          NaN               NaN  NaN  NaN           NaN        NaN
# 3          NaN               NaN  NaN  NaN           NaN        NaN
# 4          NaN               NaN  NaN  NaN           NaN        NaN
#
#   Years active Spouse(s) Children Parent(s) Genres Instruments Labels Website  \
# 0          NaN       NaN      NaN       NaN    NaN         NaN    NaN     NaN
# 1          NaN       NaN      NaN       NaN    NaN         NaN    NaN     NaN
# 2          NaN       NaN      NaN       NaN    NaN         NaN    NaN     NaN
# 3          NaN       NaN      NaN       NaN    NaN         NaN    NaN     NaN
# 4          NaN       NaN      NaN       NaN    NaN         NaN    NaN     NaN
#
#   Traditional Mandarin Type Industry Fate Founded Founder Headquarters Parent  \
# 0         NaN      NaN  NaN      NaN  NaN     NaN     NaN          NaN    NaN
# 1         NaN      NaN  NaN      NaN  NaN     NaN     NaN          NaN    NaN
# 2         NaN      NaN  NaN      NaN  NaN     NaN     NaN          NaN    NaN
# 3         NaN      NaN  NaN      NaN  NaN     NaN     NaN          NaN    NaN
# 4         NaN      NaN  NaN      NaN  NaN     NaN     NaN          NaN    NaN
#
#   Released Recorded Venue Length Label Director Producer Area Coordinates  \
# 0      NaN      NaN   NaN    NaN   NaN      NaN      NaN  NaN         NaN
# 1      NaN      NaN   NaN    NaN   NaN      NaN      NaN  NaN         NaN
# 2      NaN      NaN   NaN    NaN   NaN      NaN      NaN  NaN         NaN
# 3      NaN      NaN   NaN    NaN   NaN      NaN      NaN  NaN         NaN
# 4      NaN      NaN   NaN    NaN   NaN      NaN      NaN  NaN         NaN
#
#   Status Opening date Closing date Replaced Replaced by Name Attraction type  \
# 0    NaN          NaN          NaN      NaN         NaN  NaN             NaN
# 1    NaN          NaN          NaN      NaN         NaN  NaN             NaN
# 2    NaN          NaN          NaN      NaN         NaN  NaN             NaN
# 3    NaN          NaN          NaN      NaN         NaN  NaN             NaN
# 4    NaN          NaN          NaN      NaN         NaN  NaN             NaN
#
#   Music Duration Simplified Chinese Traditional Chinese Hanyu Pinyin  \
# 0   NaN      NaN                NaN                 NaN          NaN
# 1   NaN      NaN                NaN                 NaN          NaN
# 2   NaN      NaN                NaN                 NaN          NaN
# 3   NaN      NaN                NaN                 NaN          NaN
# 4   NaN      NaN                NaN                 NaN          NaN
#
#   Literal meaning Transcriptions Bopomofo Gwoyeu Romatzyh Wade–Giles  IPA  \
# 0             NaN            NaN      NaN             NaN        NaN  NaN
# 1             NaN            NaN      NaN             NaN        NaN  NaN
# 2             NaN            NaN      NaN             NaN        NaN  NaN
# 3             NaN            NaN      NaN             NaN        NaN  NaN
# 4             NaN            NaN      NaN             NaN        NaN  NaN
#
#   Yale Romanization Jyutping Hokkien POJ Animation by Color process Engine(s)  \
# 0               NaN      NaN         NaN          NaN           NaN       NaN
# 1               NaN      NaN         NaN          NaN           NaN       NaN
# 2               NaN      NaN         NaN          NaN           NaN       NaN
# 3               NaN      NaN         NaN          NaN           NaN       NaN
# 4               NaN      NaN         NaN          NaN           NaN       NaN
#
#   Genre(s) Actor control Production company Release(s) Format(s) Simplified  \
# 0      NaN           NaN                NaN        NaN       NaN        NaN
# 1      NaN           NaN                NaN        NaN       NaN        NaN
# 2      NaN           NaN                NaN        NaN       NaN        NaN
# 3      NaN           NaN                NaN        NaN       NaN        NaN
# 4      NaN           NaN                NaN        NaN       NaN        NaN
#
#   Characters Date premiered Place premiered Setting Original language Subject  \
# 0        NaN            NaN             NaN     NaN               NaN     NaN
# 1        NaN            NaN             NaN     NaN               NaN     NaN
# 2        NaN            NaN             NaN     NaN               NaN     NaN
# 3        NaN            NaN             NaN     NaN               NaN     NaN
# 4        NaN            NaN             NaN     NaN               NaN     NaN
#
#   Published Dewey Decimal Text Illustrator Original title  \
# 0       NaN           NaN  NaN         NaN            NaN
# 1       NaN           NaN  NaN         NaN            NaN
# 2       NaN           NaN  NaN         NaN            NaN
# 3       NaN           NaN  NaN         NaN            NaN
# 4       NaN           NaN  NaN         NaN            NaN
#
#   Published in English French Developed by Ending theme No. of seasons  \
# 0                  NaN    NaN          NaN          NaN            NaN
# 1                  NaN    NaN          NaN          NaN            NaN
# 2                  NaN    NaN          NaN          NaN            NaN
# 3                  NaN    NaN          NaN          NaN            NaN
# 4                  NaN    NaN          NaN          NaN            NaN
#
#   Nationality Portrayed by Alias Species Gender Family Alma mater  \
# 0         NaN          NaN   NaN     NaN    NaN    NaN        NaN
# 1         NaN          NaN   NaN     NaN    NaN    NaN        NaN
# 2         NaN          NaN   NaN     NaN    NaN    NaN        NaN
# 3         NaN          NaN   NaN     NaN    NaN    NaN        NaN
# 4         NaN          NaN   NaN     NaN    NaN    NaN        NaN
#
#   Camera setup Novel(s) Comics Film(s) Screen story by Hangul  \
# 0          NaN      NaN    NaN     NaN             NaN    NaN
# 1          NaN      NaN    NaN     NaN             NaN    NaN
# 2          NaN      NaN    NaN     NaN             NaN    NaN
# 3          NaN      NaN    NaN     NaN             NaN    NaN
# 4          NaN      NaN    NaN     NaN             NaN    NaN
#
#   Revised Romanization McCune–Reischauer Developer(s) Publisher(s)  \
# 0                  NaN               NaN          NaN          NaN
# 1                  NaN               NaN          NaN          NaN
# 2                  NaN               NaN          NaN          NaN
# 3                  NaN               NaN          NaN          NaN
# 4                  NaN               NaN          NaN          NaN
#
#   Designer(s) Programmer(s) Artist(s) Writer(s) Engine Platform(s) Release  \
# 0         NaN           NaN       NaN       NaN    NaN         NaN     NaN
# 1         NaN           NaN       NaN       NaN    NaN         NaN     NaN
# 2         NaN           NaN       NaN       NaN    NaN         NaN     NaN
# 3         NaN           NaN       NaN       NaN    NaN         NaN     NaN
# 4         NaN           NaN       NaN       NaN    NaN         NaN     NaN
#
#   Mode(s) Original work Television series Japanese Hepburn Literally  \
# 0     NaN           NaN               NaN      NaN     NaN       NaN
# 1     NaN           NaN               NaN      NaN     NaN       NaN
# 2     NaN           NaN               NaN      NaN     NaN       NaN
# 3     NaN           NaN               NaN      NaN     NaN       NaN
# 4     NaN           NaN               NaN      NaN     NaN       NaN
#
#   Cantonese Full name Height Seasons Chinese Other names Relatives Yiddish  \
# 0       NaN       NaN    NaN     NaN     NaN         NaN       NaN     NaN
# 1       NaN       NaN    NaN     NaN     NaN         NaN       NaN     NaN
# 2       NaN       NaN    NaN     NaN     NaN         NaN       NaN     NaN
# 3       NaN       NaN    NaN     NaN     NaN         NaN       NaN     NaN
# 4       NaN       NaN    NaN     NaN     NaN         NaN       NaN     NaN
#
#   Formerly Key people Total assets Owner Number of employees Divisions  \
# 0      NaN        NaN          NaN   NaN                 NaN       NaN
# 1      NaN        NaN          NaN   NaN                 NaN       NaN
# 2      NaN        NaN          NaN   NaN                 NaN       NaN
# 3      NaN        NaN          NaN   NaN                 NaN       NaN
# 4      NaN        NaN          NaN   NaN                 NaN       NaN
#
#   Subsidiaries Arabic Romanized Predecessor Founders Area served Products  \
# 0          NaN    NaN       NaN         NaN      NaN         NaN      NaN
# 1          NaN    NaN       NaN         NaN      NaN         NaN      NaN
# 2          NaN    NaN       NaN         NaN      NaN         NaN      NaN
# 3          NaN    NaN       NaN         NaN      NaN         NaN      NaN
# 4          NaN    NaN       NaN         NaN      NaN         NaN      NaN
#
#   Services Russian Hebrew Revenue Operating income Polish
# 0      NaN     NaN    NaN     NaN              NaN    NaN
# 1      NaN     NaN    NaN     NaN              NaN    NaN
# 2      NaN     NaN    NaN     NaN              NaN    NaN
# 3      NaN     NaN    NaN     NaN              NaN    NaN
# 4      NaN     NaN    NaN     NaN              NaN    NaN

# %%
# Convert all the names of a column in a dataframe into a list of columns
# #DataFrames #ListofColumns
wiki_movies_df.columns.tolist()
# Out:
# ['url',
#  'year',
#  'imdb_link',
#  'title',
#  'Directed by',
#  'Produced by',
#  'Screenplay by',
#  'Story by',
#  'Based on',
#  'Starring',
#  'Narrated by',
#  'Music by',
#  'Cinematography',
#  'Edited by',
#  'Productioncompany ',
#  'Distributed by',
#  'Release date',
#  'Running time',
#  'Country',
#  'Language',
#  'Budget',
#  'Box office',
#  'Written by',
#  'Genre',
#  'Theme music composer',
#  'Country of origin',
#  'Original language(s)',
#  'Producer(s)',
#  'Editor(s)',
#  'Production company(s)',
#  'Original network',
#  'Original release',
#  'Productioncompanies ',
#  'Executive producer(s)',
#  'Production location(s)',
#  'Distributor',
#  'Picture format',
#  'Audio format',
#  'Voices of',
#  'Followed by',
#  'Composer(s)',
#  'Created by',
#  'Also known as',
#  'Opening theme',
#  'No. of episodes',
#  'Preceded by',
#  'Author',
#  'Publisher',
#  'Publication date',
#  'Media type',
#  'Pages',
#  'ISBN',
#  'OCLC',
#  'LC Class',
#  'Cover artist',
#  'Series',
#  'Set in',
#  'Adaptation by',
#  'Suggested by',
#  'Biographical data',
#  'Born',
#  'Died',
#  'Resting place',
#  'Occupation',
#  'Years active',
#  'Spouse(s)',
#  'Children',
#  'Parent(s)',
#  'Genres',
#  'Instruments',
#  'Labels',
#  'Website',
#  'Traditional',
#  'Mandarin',
#  'Type',
#  'Industry',
#  'Fate',
#  'Founded',
#  'Founder',
#  'Headquarters',
#  'Parent',
#  'Released',
#  'Recorded',
#  'Venue',
#  'Length',
#  'Label',
#  'Director',
#  'Producer',
#  'Area',
#  'Coordinates',
#  'Status',
#  'Opening date',
#  'Closing date',
#  'Replaced',
#  'Replaced by',
#  'Name',
#  'Attraction type',
#  'Music',
#  'Duration',
#  'Simplified Chinese',
#  'Traditional Chinese',
#  'Hanyu Pinyin',
#  'Literal meaning',
#  'Transcriptions',
#  'Bopomofo',
#  'Gwoyeu Romatzyh',
#  'Wade–Giles',
#  'IPA',
#  'Yale Romanization',
#  'Jyutping',
#  'Hokkien POJ',
#  'Animation by',
#  'Color process',
#  'Engine(s)',
#  'Genre(s)',
#  'Actor control',
#  'Production company',
#  'Release(s)',
#  'Format(s)',
#  'Simplified',
#  'Characters',
#  'Date premiered',
#  'Place premiered',
#  'Setting',
#  'Original language',
#  'Subject',
#  'Published',
#  'Dewey Decimal',
#  'Text',
#  'Illustrator',
#  'Original title',
#  'Published in English',
#  'French',
#  'Developed by',
#  'Ending theme',
#  'No. of seasons',
#  'Nationality',
#  'Portrayed by',
#  'Alias',
#  'Species',
#  'Gender',
#  'Family',
#  'Alma mater',
#  'Camera setup',
#  'Novel(s)',
#  'Comics',
#  'Film(s)',
#  'Screen story by',
#  'Hangul',
#  'Revised Romanization',
#  'McCune–Reischauer',
#  'Developer(s)',
#  'Publisher(s)',
#  'Designer(s)',
#  'Programmer(s)',
#  'Artist(s)',
#  'Writer(s)',
#  'Engine',
#  'Platform(s)',
#  'Release',
#  'Mode(s)',
#  'Original work',
#  'Television series',
#  'Japanese',
#  'Hepburn',
#  'Literally',
#  'Cantonese',
#  'Full name',
#  'Height',
#  'Seasons',
#  'Chinese',
#  'Other names',
#  'Relatives',
#  'Yiddish',
#  'Formerly',
#  'Key people',
#  'Total assets',
#  'Owner',
#  'Number of employees',
#  'Divisions',
#  'Subsidiaries',
#  'Arabic',
#  'Romanized',
#  'Predecessor',
#  'Founders',
#  'Area served',
#  'Products',
#  'Services',
#  'Russian',
#  'Hebrew',
#  'Revenue',
#  'Operating income',
#  'Polish']

# %%
# #DataFrame #Sort #Filter
# Use a list comprehension on our DataFrame - It's a compact way to 
# apply a function to every element in a list
# The resulting list will only have elements where 
# the filter expression evaluates to True.
# Create a list comprehension with the filter expression 
# we created and save that to an intermediate variable
wiki_movies = [movie for movie in wiki_movies_raw
               if ('Director' in movie or 'Directed by' in movie)
                   and 'imdb_link' in movie
                   and 'No. of episodes' not in movie]
len(wiki_movies)
# Out:
# 7076

# %%
# Find objects that have a key 'Arabic' that has a value
wiki_movies_df[wiki_movies_df['Arabic'].notnull()]
# Out:
#                                                   url    year  \
# 7060  https://en.wikipedia.org/wiki/The_Insult_(film)  2018.0
# 7293   https://en.wikipedia.org/wiki/Capernaum_(film)  2018.0
#
#                                   imdb_link       title    Directed by  \
# 7060  https://www.imdb.com/title/tt7048622/  The Insult   Ziad Doueiri
# 7293  https://www.imdb.com/title/tt8267604/   Capernaum  Nadine Labaki
#
#                                             Produced by  \
# 7060  [Rachid Bouchareb, Jean Bréhat, Julie Gayet, A...
# 7293                    [Michel Merkt, Khaled Mouzanar]
#
#                                           Screenplay by  \
# 7060                                                NaN
# 7293  [Nadine Labaki, Jihad Hojaily, Michelle Keserw...
#
#                                                Story by Based on  \
# 7060                                                NaN      NaN
# 7293  [Georges Khabbaz, Nadine Labaki, Michelle Kese...      NaN
#
#                                                Starring Narrated by  \
# 7060                       [Adel Karam, Kamel El Basha]         NaN
# 7293  [Zain Al Rafeea, Yordanos Shiferaw, Boluwatife...         NaN
#
#              Music by    Cinematography           Edited by  \
# 7060      Éric Neveux  Tommaso Fiorilli  Dominique Marcombe
# 7293  Khaled Mouzanar  Christopher Aoun     Konstantin Bock
#
#                                      Productioncompany   \
# 7060  [Ezekiel Films, Tessalit Productions, Rouge In...
# 7293                                         Mooz Films
#
#                                          Distributed by  \
# 7060  [Diaphana Films, (France), Italia Film, (Lebanon]
# 7293                             Sony Pictures Classics
#
#                                            Release date Running time  \
# 7060  [31 August 2017, (, 2017-08-31, ), (, Venice, ...  112 minutes
# 7293  [17 May 2018, (, 2018-05-17, ), (, Cannes, ), ...  126 minutes
#
#                 Country           Language      Budget     Box office  \
# 7060  [France, Lebanon]    Lebanese Arabic         NaN   $1.6 million
# 7293            Lebanon  [Arabic, Amharic]  $4 million  $68.6 million
#
#                         Written by Genre Theme music composer  \
# 7060  [Ziad Doueiri, Joelle Touma]   NaN                  NaN
# 7293                           NaN   NaN                  NaN
#
#      Country of origin Original language(s) Producer(s) Editor(s)  \
# 7060               NaN                  NaN         NaN       NaN
# 7293               NaN                  NaN         NaN       NaN
#
#      Production company(s) Original network Original release  \
# 7060                   NaN              NaN              NaN
# 7293                   NaN              NaN              NaN
#
#      Productioncompanies  Executive producer(s) Production location(s)  \
# 7060                  NaN                   NaN                    NaN
# 7293                  NaN                   NaN                    NaN
#
#      Distributor Picture format Audio format Voices of Followed by  \
# 7060         NaN            NaN          NaN       NaN         NaN
# 7293         NaN            NaN          NaN       NaN         NaN
#
#      Composer(s) Created by Also known as Opening theme No. of episodes  \
# 7060         NaN        NaN           NaN           NaN             NaN
# 7293         NaN        NaN           NaN           NaN             NaN
#
#      Preceded by Author Publisher Publication date Media type Pages ISBN OCLC  \
# 7060         NaN    NaN       NaN              NaN        NaN   NaN  NaN  NaN
# 7293         NaN    NaN       NaN              NaN        NaN   NaN  NaN  NaN
#
#      LC Class Cover artist Series Set in Adaptation by Suggested by  \
# 7060      NaN          NaN    NaN    NaN           NaN          NaN
# 7293      NaN          NaN    NaN    NaN           NaN          NaN
#
#      Biographical data Born Died Resting place Occupation Years active  \
# 7060               NaN  NaN  NaN           NaN        NaN          NaN
# 7293               NaN  NaN  NaN           NaN        NaN          NaN
#
#      Spouse(s) Children Parent(s) Genres Instruments Labels Website  \
# 7060       NaN      NaN       NaN    NaN         NaN    NaN     NaN
# 7293       NaN      NaN       NaN    NaN         NaN    NaN     NaN
#
#      Traditional Mandarin Type Industry Fate Founded Founder Headquarters  \
# 7060         NaN      NaN  NaN      NaN  NaN     NaN     NaN          NaN
# 7293         NaN      NaN  NaN      NaN  NaN     NaN     NaN          NaN
#
#      Parent Released Recorded Venue Length Label Director Producer Area  \
# 7060    NaN      NaN      NaN   NaN    NaN   NaN      NaN      NaN  NaN
# 7293    NaN      NaN      NaN   NaN    NaN   NaN      NaN      NaN  NaN
#
#      Coordinates Status Opening date Closing date Replaced Replaced by Name  \
# 7060         NaN    NaN          NaN          NaN      NaN         NaN  NaN
# 7293         NaN    NaN          NaN          NaN      NaN         NaN  NaN
#
#      Attraction type Music Duration Simplified Chinese Traditional Chinese  \
# 7060             NaN   NaN      NaN                NaN                 NaN
# 7293             NaN   NaN      NaN                NaN                 NaN
#
#      Hanyu Pinyin Literal meaning Transcriptions Bopomofo Gwoyeu Romatzyh  \
# 7060          NaN             NaN            NaN      NaN             NaN
# 7293          NaN             NaN            NaN      NaN             NaN
#
#      Wade–Giles  IPA Yale Romanization Jyutping Hokkien POJ Animation by  \
# 7060        NaN  NaN               NaN      NaN         NaN          NaN
# 7293        NaN  NaN               NaN      NaN         NaN          NaN
#
#      Color process Engine(s) Genre(s) Actor control Production company  \
# 7060           NaN       NaN      NaN           NaN                NaN
# 7293           NaN       NaN      NaN           NaN                NaN
#
#      Release(s) Format(s) Simplified Characters Date premiered  \
# 7060        NaN       NaN        NaN        NaN            NaN
# 7293        NaN       NaN        NaN        NaN            NaN
#
#      Place premiered Setting Original language Subject Published  \
# 7060             NaN     NaN               NaN     NaN       NaN
# 7293             NaN     NaN               NaN     NaN       NaN
#
#      Dewey Decimal Text Illustrator Original title Published in English  \
# 7060           NaN  NaN         NaN            NaN                  NaN
# 7293           NaN  NaN         NaN            NaN                  NaN
#
#      French Developed by Ending theme No. of seasons Nationality Portrayed by  \
# 7060    NaN          NaN          NaN            NaN         NaN          NaN
# 7293    NaN          NaN          NaN            NaN         NaN          NaN
#
#      Alias Species Gender Family Alma mater Camera setup Novel(s) Comics  \
# 7060   NaN     NaN    NaN    NaN        NaN          NaN      NaN    NaN
# 7293   NaN     NaN    NaN    NaN        NaN          NaN      NaN    NaN
#
#      Film(s) Screen story by Hangul Revised Romanization McCune–Reischauer  \
# 7060     NaN             NaN    NaN                  NaN               NaN
# 7293     NaN             NaN    NaN                  NaN               NaN
#
#      Developer(s) Publisher(s) Designer(s) Programmer(s) Artist(s) Writer(s)  \
# 7060          NaN          NaN         NaN           NaN       NaN       NaN
# 7293          NaN          NaN         NaN           NaN       NaN       NaN
#
#      Engine Platform(s) Release Mode(s) Original work Television series  \
# 7060    NaN         NaN     NaN     NaN           NaN               NaN
# 7293    NaN         NaN     NaN     NaN           NaN               NaN
#
#      Japanese Hepburn    Literally Cantonese Full name Height Seasons Chinese  \
# 7060      NaN     NaN  Case No. 23       NaN       NaN    NaN     NaN     NaN
# 7293      NaN     NaN          NaN       NaN       NaN    NaN     NaN     NaN
#
#      Other names Relatives Yiddish Formerly Key people Total assets Owner  \
# 7060         NaN       NaN     NaN      NaN        NaN          NaN   NaN
# 7293         NaN       NaN     NaN      NaN        NaN          NaN   NaN
#
#      Number of employees Divisions Subsidiaries       Arabic        Romanized  \
# 7060                 NaN       NaN          NaN  قضية رقم ٢٣  Qadiyya raqm 23
# 7293                 NaN       NaN          NaN    کفرناحوم‎              NaN
#
#      Predecessor Founders Area served Products Services Russian Hebrew  \
# 7060         NaN      NaN         NaN      NaN      NaN     NaN    NaN
# 7293         NaN      NaN         NaN      NaN      NaN     NaN    NaN
#
#      Revenue Operating income Polish
# 7060     NaN              NaN    NaN
# 7293     NaN              NaN    NaN

# %%
wiki_movies_df[wiki_movies_df['Arabic'].notnull()]['url']
# Out:
# 7060    https://en.wikipedia.org/wiki/The_Insult_(film)
# 7293     https://en.wikipedia.org/wiki/Capernaum_(film)
# Name: url, dtype: object

# %%
# List the columns in the dataframe
sorted(wiki_movies_df.columns.tolist())
# Out:
# ['Actor control',
#  'Adaptation by',
#  'Alias',
#  'Alma mater',
#  'Also known as',
#  'Animation by',
#  'Arabic',
#  'Area',
#  'Area served',
#  'Artist(s)',
#  'Attraction type',
#  'Audio format',
#  'Author',
#  'Based on',
#  'Biographical data',
#  'Bopomofo',
#  'Born',
#  'Box office',
#  'Budget',
#  'Camera setup',
#  'Cantonese',
#  'Characters',
#  'Children',
#  'Chinese',
#  'Cinematography',
#  'Closing date',
#  'Color process',
#  'Comics',
#  'Composer(s)',
#  'Coordinates',
#  'Country',
#  'Country of origin',
#  'Cover artist',
#  'Created by',
#  'Date premiered',
#  'Designer(s)',
#  'Developed by',
#  'Developer(s)',
#  'Dewey Decimal',
#  'Died',
#  'Directed by',
#  'Director',
#  'Distributed by',
#  'Distributor',
#  'Divisions',
#  'Duration',
#  'Edited by',
#  'Editor(s)',
#  'Ending theme',
#  'Engine',
#  'Engine(s)',
#  'Executive producer(s)',
#  'Family',
#  'Fate',
#  'Film(s)',
#  'Followed by',
#  'Format(s)',
#  'Formerly',
#  'Founded',
#  'Founder',
#  'Founders',
#  'French',
#  'Full name',
#  'Gender',
#  'Genre',
#  'Genre(s)',
#  'Genres',
#  'Gwoyeu Romatzyh',
#  'Hangul',
#  'Hanyu Pinyin',
#  'Headquarters',
#  'Hebrew',
#  'Height',
#  'Hepburn',
#  'Hokkien POJ',
#  'IPA',
#  'ISBN',
#  'Illustrator',
#  'Industry',
#  'Instruments',
#  'Japanese',
#  'Jyutping',
#  'Key people',
#  'LC Class',
#  'Label',
#  'Labels',
#  'Language',
#  'Length',
#  'Literal meaning',
#  'Literally',
#  'Mandarin',
#  'McCune–Reischauer',
#  'Media type',
#  'Mode(s)',
#  'Music',
#  'Music by',
#  'Name',
#  'Narrated by',
#  'Nationality',
#  'No. of episodes',
#  'No. of seasons',
#  'Novel(s)',
#  'Number of employees',
#  'OCLC',
#  'Occupation',
#  'Opening date',
#  'Opening theme',
#  'Operating income',
#  'Original language',
#  'Original language(s)',
#  'Original network',
#  'Original release',
#  'Original title',
#  'Original work',
#  'Other names',
#  'Owner',
#  'Pages',
#  'Parent',
#  'Parent(s)',
#  'Picture format',
#  'Place premiered',
#  'Platform(s)',
#  'Polish',
#  'Portrayed by',
#  'Preceded by',
#  'Predecessor',
#  'Produced by',
#  'Producer',
#  'Producer(s)',
#  'Production company',
#  'Production company(s)',
#  'Production location(s)',
#  'Productioncompanies ',
#  'Productioncompany ',
#  'Products',
#  'Programmer(s)',
#  'Publication date',
#  'Published',
#  'Published in English',
#  'Publisher',
#  'Publisher(s)',
#  'Recorded',
#  'Relatives',
#  'Release',
#  'Release date',
#  'Release(s)',
#  'Released',
#  'Replaced',
#  'Replaced by',
#  'Resting place',
#  'Revenue',
#  'Revised Romanization',
#  'Romanized',
#  'Running time',
#  'Russian',
#  'Screen story by',
#  'Screenplay by',
#  'Seasons',
#  'Series',
#  'Services',
#  'Set in',
#  'Setting',
#  'Simplified',
#  'Simplified Chinese',
#  'Species',
#  'Spouse(s)',
#  'Starring',
#  'Status',
#  'Story by',
#  'Subject',
#  'Subsidiaries',
#  'Suggested by',
#  'Television series',
#  'Text',
#  'Theme music composer',
#  'Total assets',
#  'Traditional',
#  'Traditional Chinese',
#  'Transcriptions',
#  'Type',
#  'Venue',
#  'Voices of',
#  'Wade–Giles',
#  'Website',
#  'Writer(s)',
#  'Written by',
#  'Yale Romanization',
#  'Years active',
#  'Yiddish',
#  'imdb_link',
#  'title',
#  'url',
#  'year']

# %%
pd.set_option('display.max_columns', None)

wiki_movies_df[wiki_movies_df['Alias'].notnull()]['Alias']
# Out:
# 2090    Quincy Magoo
# Name: Alias, dtype: object

# %%
wiki_movies_df[wiki_movies_df['Alias'].notnull()]
# Out:
#                                           url    year  \
# 2090  https://en.wikipedia.org/wiki/Mr._Magoo  1997.0
#
#                                   imdb_link      title Directed by  \
# 2090  https://www.imdb.com/title/tt1044551/  Mr. Magoo         NaN
#
#      Produced by Screenplay by Story by Based on Starring Narrated by  \
# 2090         NaN           NaN      NaN      NaN      NaN         NaN
#
#      Music by Cinematography Edited by Productioncompany  Distributed by  \
# 2090      NaN            NaN       NaN                NaN            NaN
#
#      Release date Running time Country Language Budget Box office Written by  \
# 2090          NaN          NaN     NaN      NaN    NaN        NaN        NaN
#
#      Genre Theme music composer Country of origin Original language(s)  \
# 2090   NaN                  NaN               NaN                  NaN
#
#      Producer(s) Editor(s) Production company(s) Original network  \
# 2090         NaN       NaN                   NaN              NaN
#
#      Original release Productioncompanies  Executive producer(s)  \
# 2090              NaN                  NaN                   NaN
#
#      Production location(s) Distributor Picture format Audio format Voices of  \
# 2090                    NaN         NaN            NaN          NaN       NaN
#
#      Followed by Composer(s)  \
# 2090         NaN         NaN
#
#                                              Created by Also known as  \
# 2090  [Millard Kaufman, John Hubley, Willis Pyle, [1...           NaN
#
#      Opening theme No. of episodes Preceded by Author Publisher  \
# 2090           NaN             NaN         NaN    NaN       NaN
#
#      Publication date Media type Pages ISBN OCLC LC Class Cover artist Series  \
# 2090              NaN        NaN   NaN  NaN  NaN      NaN          NaN    NaN
#
#      Set in Adaptation by Suggested by Biographical data Born Died  \
# 2090    NaN           NaN          NaN               NaN  NaN  NaN
#
#      Resting place Occupation Years active Spouse(s) Children Parent(s)  \
# 2090           NaN        NaN          NaN       NaN      NaN       NaN
#
#      Genres Instruments Labels Website Traditional Mandarin Type Industry  \
# 2090    NaN         NaN    NaN     NaN         NaN      NaN  NaN      NaN
#
#      Fate Founded Founder Headquarters Parent Released Recorded Venue Length  \
# 2090  NaN     NaN     NaN          NaN    NaN      NaN      NaN   NaN    NaN
#
#      Label Director Producer Area Coordinates Status Opening date  \
# 2090   NaN      NaN      NaN  NaN         NaN    NaN          NaN
#
#      Closing date Replaced Replaced by Name Attraction type Music Duration  \
# 2090          NaN      NaN         NaN  NaN             NaN   NaN      NaN
#
#      Simplified Chinese Traditional Chinese Hanyu Pinyin Literal meaning  \
# 2090                NaN                 NaN          NaN             NaN
#
#      Transcriptions Bopomofo Gwoyeu Romatzyh Wade–Giles  IPA  \
# 2090            NaN      NaN             NaN        NaN  NaN
#
#      Yale Romanization Jyutping Hokkien POJ Animation by Color process  \
# 2090               NaN      NaN         NaN          NaN           NaN
#
#      Engine(s) Genre(s) Actor control Production company Release(s) Format(s)  \
# 2090       NaN      NaN           NaN                NaN        NaN       NaN
#
#      Simplified Characters Date premiered Place premiered Setting  \
# 2090        NaN        NaN            NaN             NaN     NaN
#
#      Original language Subject Published Dewey Decimal Text Illustrator  \
# 2090               NaN     NaN       NaN           NaN  NaN         NaN
#
#      Original title Published in English French Developed by Ending theme  \
# 2090            NaN                  NaN    NaN          NaN          NaN
#
#      No. of seasons Nationality  \
# 2090            NaN    American
#
#                                            Portrayed by         Alias Species  \
# 2090  [Jim Backus, (1949–1989), Leslie Nielsen, (fil...  Quincy Magoo   Human
#
#      Gender                                             Family  \
# 2090   Male  [Linda Magoo (mother), Granny Magoo (grandmoth...
#
#               Alma mater Camera setup Novel(s) Comics Film(s) Screen story by  \
# 2090  Rutgers University          NaN      NaN    NaN     NaN             NaN
#
#      Hangul Revised Romanization McCune–Reischauer Developer(s) Publisher(s)  \
# 2090    NaN                  NaN               NaN          NaN          NaN
#
#      Designer(s) Programmer(s) Artist(s) Writer(s) Engine Platform(s) Release  \
# 2090         NaN           NaN       NaN       NaN    NaN         NaN     NaN
#
#      Mode(s) Original work Television series Japanese Hepburn Literally  \
# 2090     NaN           NaN               NaN      NaN     NaN       NaN
#
#      Cantonese Full name Height Seasons Chinese Other names Relatives Yiddish  \
# 2090       NaN       NaN    NaN     NaN     NaN         NaN       NaN     NaN
#
#      Formerly Key people Total assets Owner Number of employees Divisions  \
# 2090      NaN        NaN          NaN   NaN                 NaN       NaN
#
#      Subsidiaries Arabic Romanized Predecessor Founders Area served Products  \
# 2090          NaN    NaN       NaN         NaN      NaN         NaN      NaN
#
#      Services Russian Hebrew Revenue Operating income Polish
# 2090      NaN     NaN    NaN     NaN              NaN    NaN

# %%
wiki_movies_df[wiki_movies_df['Also known as'].notnull()]
# Out:
#                                                     url    year  \
# 71      https://en.wikipedia.org/wiki/Eyes_on_the_Prize  1990.0
# 1395  https://en.wikipedia.org/wiki/Night_Watch_(199...  1995.0
#
#                                   imdb_link              title  \
# 71    https://www.imdb.com/title/tt0092999/  Eyes on the Prize
# 1395  https://www.imdb.com/title/tt0113984/         Nightwatch
#
#                                             Directed by Produced by  \
# 71    [Orlando Bagwell, Sheila Curran Bernard, Calli...         NaN
# 1395                                      David Jackson         NaN
#
#      Screenplay by Story by Based on                             Starring  \
# 71             NaN      NaN      NaN                                  NaN
# 1395           NaN      NaN      NaN  [Pierce Brosnan, ,, Alexandra Paul]
#
#       Narrated by Music by  Cinematography Edited by Productioncompany   \
# 71    Julian Bond      NaN             NaN       NaN                NaN
# 1395          NaN      NaN  Michael Negrin       NaN                NaN
#
#      Distributed by Release date Running time Country Language      Budget  \
# 71              NaN          NaN   60 minutes     NaN      NaN         NaN
# 1395            NaN          NaN  101 minutes     NaN      NaN  $6,000,000
#
#      Box office                                         Written by  \
# 71          NaN                                                NaN
# 1395        NaN  [Alistair MacLean, (story),, Alistair MacNeill...
#
#                    Genre Theme music composer Country of origin  \
# 71      Documentary film                  NaN     United States
# 1395  [Action, Thriller]           John Scott     United States
#
#      Original language(s)                                        Producer(s)  \
# 71                English                                                NaN
# 1395              English  [Boris Dmitrovic, (line producer), Mike Mihali...
#
#                                               Editor(s) Production company(s)  \
# 71    [Lillian Benson, Betty Ciccarelli, Daniel Eise...             Blackside
# 1395                                  Eric Boyd-Perkins     J&M Entertainment
#
#      Original network                                   Original release  \
# 71                PBS  [January 21, 1987, (, 1987-01-21, ), –, March ...
# 1395              USA               [October 13, 1995, (, 1995-10-13, )]
#
#      Productioncompanies  Executive producer(s) Production location(s)  \
# 71                    NaN         Henry Hampton          United States
# 1395                  NaN                   NaN                    NaN
#
#       Distributor   Picture format Audio format Voices of Followed by  \
# 71            NaN  Black-and-white          NaN       NaN         NaN
# 1395  USA Network            Color       Stereo       NaN         NaN
#
#      Composer(s) Created by                                Also known as  \
# 71           NaN        NaN  [Eyes on the Prize I, Eyes on the Prize II]
# 1395         NaN        NaN                    Detonator II: Night Watch
#
#                             Opening theme No. of episodes Preceded by Author  \
# 71    [", Keep Your Eyes on the Prize, "]              14         NaN    NaN
# 1395                                  NaN             NaN         NaN    NaN
#
#      Publisher Publication date Media type Pages ISBN OCLC LC Class  \
# 71         NaN              NaN        NaN   NaN  NaN  NaN      NaN
# 1395       NaN              NaN        NaN   NaN  NaN  NaN      NaN
#
#      Cover artist Series Set in Adaptation by Suggested by Biographical data  \
# 71            NaN    NaN    NaN           NaN          NaN               NaN
# 1395          NaN    NaN    NaN           NaN          NaN               NaN
#
#      Born Died Resting place Occupation Years active Spouse(s) Children  \
# 71    NaN  NaN           NaN        NaN          NaN       NaN      NaN
# 1395  NaN  NaN           NaN        NaN          NaN       NaN      NaN
#
#      Parent(s) Genres Instruments Labels Website Traditional Mandarin Type  \
# 71         NaN    NaN         NaN    NaN     NaN         NaN      NaN  NaN
# 1395       NaN    NaN         NaN    NaN     NaN         NaN      NaN  NaN
#
#      Industry Fate Founded Founder Headquarters Parent Released Recorded  \
# 71        NaN  NaN     NaN     NaN          NaN    NaN      NaN      NaN
# 1395      NaN  NaN     NaN     NaN          NaN    NaN      NaN      NaN
#
#      Venue Length Label Director Producer Area Coordinates Status  \
# 71     NaN    NaN   NaN      NaN      NaN  NaN         NaN    NaN
# 1395   NaN    NaN   NaN      NaN      NaN  NaN         NaN    NaN
#
#      Opening date Closing date Replaced Replaced by Name Attraction type  \
# 71            NaN          NaN      NaN         NaN  NaN             NaN
# 1395          NaN          NaN      NaN         NaN  NaN             NaN
#
#      Music Duration Simplified Chinese Traditional Chinese Hanyu Pinyin  \
# 71     NaN      NaN                NaN                 NaN          NaN
# 1395   NaN      NaN                NaN                 NaN          NaN
#
#      Literal meaning Transcriptions Bopomofo Gwoyeu Romatzyh Wade–Giles  IPA  \
# 71               NaN            NaN      NaN             NaN        NaN  NaN
# 1395             NaN            NaN      NaN             NaN        NaN  NaN
#
#      Yale Romanization Jyutping Hokkien POJ Animation by Color process  \
# 71                 NaN      NaN         NaN          NaN           NaN
# 1395               NaN      NaN         NaN          NaN           NaN
#
#      Engine(s) Genre(s) Actor control Production company Release(s) Format(s)  \
# 71         NaN      NaN           NaN                NaN        NaN       NaN
# 1395       NaN      NaN           NaN                NaN        NaN       NaN
#
#      Simplified Characters Date premiered Place premiered Setting  \
# 71          NaN        NaN            NaN             NaN     NaN
# 1395        NaN        NaN            NaN             NaN     NaN
#
#      Original language Subject Published Dewey Decimal Text Illustrator  \
# 71                 NaN     NaN       NaN           NaN  NaN         NaN
# 1395               NaN     NaN       NaN           NaN  NaN         NaN
#
#      Original title Published in English French Developed by Ending theme  \
# 71              NaN                  NaN    NaN          NaN          NaN
# 1395            NaN                  NaN    NaN          NaN          NaN
#
#      No. of seasons Nationality Portrayed by Alias Species Gender Family  \
# 71              NaN         NaN          NaN   NaN     NaN    NaN    NaN
# 1395            NaN         NaN          NaN   NaN     NaN    NaN    NaN
#
#      Alma mater Camera setup Novel(s) Comics Film(s) Screen story by Hangul  \
# 71          NaN          NaN      NaN    NaN     NaN             NaN    NaN
# 1395        NaN          NaN      NaN    NaN     NaN             NaN    NaN
#
#      Revised Romanization McCune–Reischauer Developer(s) Publisher(s)  \
# 71                    NaN               NaN          NaN          NaN
# 1395                  NaN               NaN          NaN          NaN
#
#      Designer(s) Programmer(s) Artist(s) Writer(s) Engine Platform(s) Release  \
# 71           NaN           NaN       NaN       NaN    NaN         NaN     NaN
# 1395         NaN           NaN       NaN       NaN    NaN         NaN     NaN
#
#      Mode(s) Original work Television series Japanese Hepburn Literally  \
# 71       NaN           NaN               NaN      NaN     NaN       NaN
# 1395     NaN           NaN               NaN      NaN     NaN       NaN
#
#      Cantonese Full name Height Seasons Chinese Other names Relatives Yiddish  \
# 71         NaN       NaN    NaN     NaN     NaN         NaN       NaN     NaN
# 1395       NaN       NaN    NaN     NaN     NaN         NaN       NaN     NaN
#
#      Formerly Key people Total assets Owner Number of employees Divisions  \
# 71        NaN        NaN          NaN   NaN                 NaN       NaN
# 1395      NaN        NaN          NaN   NaN                 NaN       NaN
#
#      Subsidiaries Arabic Romanized Predecessor Founders Area served Products  \
# 71            NaN    NaN       NaN         NaN      NaN         NaN      NaN
# 1395          NaN    NaN       NaN         NaN      NaN         NaN      NaN
#
#      Services Russian Hebrew Revenue Operating income Polish
# 71        NaN     NaN    NaN     NaN              NaN    NaN
# 1395      NaN     NaN    NaN     NaN              NaN    NaN

# %%
wiki_movies_df[wiki_movies_df['Also known as'].notnull()]['Also known as']
# Out:
# 71      [Eyes on the Prize I, Eyes on the Prize II]
# 1395                      Detonator II: Night Watch
# Name: Also known as, dtype: object

# %%
# Add in code to handle the alternative titles. 
# This function will take any alternative title values in
# the list of keys/columns that could be in the object
# and will add the value into a dictionary  


def clean_movie(movie):

    # Statement to copy dictionary - This is an on-descructive Copy
    # We can use the same name because it is a local variable and the local
    # variable won't override the global variable "movie"    
    movie = dict(movie) #create a non-destructive copy

    # Creates the dictionary that will hold the alternate title values if found
    alt_titles = {}
    
    # Loop through a list of all alternative title keys.
    for key in ['Also known as','Arabic','Cantonese','Chinese','French',
                'Hangul','Hebrew','Hepburn','Japanese','Literally',
                'Mandarin','McCune–Reischauer','Original title','Polish',
                'Revised Romanization','Romanized','Russian',
                'Simplified','Traditional','Yiddish']:

        # Check if the current key exists in the movie object.
        if key in movie:
            # If so, remove the key-value pair and add to the alternative titles dictionary.
            alt_titles[key] = movie[key]
            movie.pop(key)

        if len(alt_titles) > 0:
            movie['alt_titles'] = alt_titles

    return movie

# %%
# We can make a list of cleaned movies with a list comprehension:
clean_movies = [clean_movie(movie) for movie in wiki_movies]

# %%
# To see the first five records in the list of dictionaries
clean_movies[:5]
# Out:
# [{'url': 'https://en.wikipedia.org/wiki/The_Adventures_of_Ford_Fairlane',
#   'year': 1990,
#   'imdb_link': 'https://www.imdb.com/title/tt0098987/',
#   'title': 'The Adventures of Ford Fairlane',
#   'Directed by': 'Renny Harlin',
#   'Produced by': ['Steve Perry', 'Joel Silver'],
#   'Screenplay by': ['David Arnott', 'James Cappe', 'Daniel Waters'],
#   'Story by': ['David Arnott', 'James Cappe'],
#   'Based on': ['Characters', 'by Rex Weiner'],
#   'Starring': ['Andrew Dice Clay',
#    'Wayne Newton',
#    'Priscilla Presley',
#    'Lauren Holly',
#    'Morris Day',
#    'Robert Englund',
#    "Ed O'Neill"],
#   'Narrated by': 'Andrew "Dice" Clay',
#   'Music by': ['Cliff Eidelman', 'Yello'],
#   'Cinematography': 'Oliver Wood',
#   'Edited by': 'Michael Tronick',
#   'Productioncompany ': 'Silver Pictures',
#   'Distributed by': '20th Century Fox',
#   'Release date': ['July 11, 1990', '(', '1990-07-11', ')'],
#   'Running time': '102 minutes',
#   'Country': 'United States',
#   'Language': 'English',
#   'Budget': '$20 million',
#   'Box office': '$21.4 million'},
#  {'url': 'https://en.wikipedia.org/wiki/After_Dark,_My_Sweet',
#   'year': 1990,
#   'imdb_link': 'https://www.imdb.com/title/tt0098994/',
#   'title': 'After Dark, My Sweet',
#   'Directed by': 'James Foley',
#   'Produced by': ['Ric Kidney', 'Robert Redlin'],
#   'Screenplay by': ['James Foley', 'Robert Redlin'],
#   'Based on': ['the novel', 'After Dark, My Sweet', 'by', 'Jim Thompson'],
#   'Starring': ['Jason Patric',
#    'Rachel Ward',
#    'Bruce Dern',
#    'George Dickerson'],
#   'Music by': 'Maurice Jarre',
#   'Cinematography': 'Mark Plummer',
#   'Edited by': 'Howard E. Smith',
#   'Productioncompany ': 'Avenue Pictures',
#   'Distributed by': 'Avenue Pictures',
#   'Release date': ['May 17, 1990',
#    '(',
#    '1990-05-17',
#    ')',
#    '(Cannes Film Market)',
#    'August 24, 1990',
#    '(',
#    '1990-08-24',
#    ')',
#    '(United States)'],
#   'Running time': '114 minutes',
#   'Country': 'United States',
#   'Language': 'English',
#   'Budget': '$6 million',
#   'Box office': '$2.7 million'},
#  {'url': 'https://en.wikipedia.org/wiki/Air_America_(film)',
#   'year': 1990,
#   'imdb_link': 'https://www.imdb.com/title/tt0099005/',
#   'title': 'Air America',
#   'Directed by': 'Roger Spottiswoode',
#   'Produced by': 'Daniel Melnick',
#   'Screenplay by': ['John Eskow', 'Richard Rush'],
#   'Based on': ['Air America', 'by', 'Christopher Robbins'],
#   'Starring': ['Mel Gibson',
#    'Robert Downey Jr.',
#    'Nancy Travis',
#    'David Marshall Grant',
#    'Lane Smith'],
#   'Music by': 'Charles Gross',
#   'Cinematography': 'Roger Deakins',
#   'Edited by': ['John Bloom', 'Lois Freeman-Fox'],
#   'Productioncompany ': ['Carolco Pictures', 'IndieProd Company'],
#   'Distributed by': 'TriStar Pictures',
#   'Release date': ['August 10, 1990', '(', '1990-08-10', ')'],
#   'Running time': '113 minutes',
#   'Country': 'United States',
#   'Language': ['English', 'Lao'],
#   'Budget': '$35 million',
#   'Box office': '$57,718,089'},
#  {'url': 'https://en.wikipedia.org/wiki/Alice_(1990_film)',
#   'year': 1990,
#   'imdb_link': 'https://www.imdb.com/title/tt0099012/',
#   'title': 'Alice',
#   'Directed by': 'Woody Allen',
#   'Produced by': 'Robert Greenhut',
#   'Written by': 'Woody Allen',
#   'Starring': ['Alec Baldwin',
#    'Blythe Danner',
#    'Judy Davis',
#    'Mia Farrow',
#    'William Hurt',
#    'Keye Luke',
#    'Joe Mantegna',
#    'Bernadette Peters'],
#   'Cinematography': 'Carlo Di Palma',
#   'Edited by': 'Susan E. Morse',
#   'Distributed by': 'Orion Pictures',
#   'Release date': ['December 25, 1990', '(', '1990-12-25', ')'],
#   'Running time': '106 minutes',
#   'Country': 'United States',
#   'Language': 'English',
#   'Budget': '$12 million',
#   'Box office': '$7,331,647'},
#  {'url': 'https://en.wikipedia.org/wiki/Almost_an_Angel',
#   'year': 1990,
#   'imdb_link': 'https://www.imdb.com/title/tt0099018/',
#   'title': 'Almost an Angel',
#   'Directed by': 'John Cornell',
#   'Produced by': 'John Cornell',
#   'Written by': 'Paul Hogan',
#   'Starring': ['Paul Hogan', 'Elias Koteas', 'Linda Kozlowski'],
#   'Music by': 'Maurice Jarre',
#   'Cinematography': 'Russell Boyd',
#   'Edited by': 'David Stiven',
#   'Distributed by': 'Paramount Pictures',
#   'Release date': 'December 19, 1990',
#   'Running time': '95 minutes',
#   'Country': 'US',
#   'Language': 'English',
#   'Budget': '$25 million',
#   'Box office': '$6,939,946 (USA)'}]

# %%
# Create a dataframe from the list of dictionaries 
wiki_movies_df = pd.DataFrame(clean_movies)

# Prints out the list of columns in the DataFrame
sorted(wiki_movies_df.columns.tolist())
# Out:
# ['Adaptation by',
#  'Animation by',
#  'Audio format',
#  'Based on',
#  'Box office',
#  'Budget',
#  'Cinematography',
#  'Color process',
#  'Composer(s)',
#  'Country',
#  'Country of origin',
#  'Created by',
#  'Directed by',
#  'Director',
#  'Distributed by',
#  'Distributor',
#  'Edited by',
#  'Editor(s)',
#  'Executive producer(s)',
#  'Followed by',
#  'Genre',
#  'Label',
#  'Language',
#  'Length',
#  'Music by',
#  'Narrated by',
#  'Original language(s)',
#  'Original network',
#  'Original release',
#  'Picture format',
#  'Preceded by',
#  'Produced by',
#  'Producer',
#  'Producer(s)',
#  'Production company(s)',
#  'Production location(s)',
#  'Productioncompanies ',
#  'Productioncompany ',
#  'Recorded',
#  'Release date',
#  'Released',
#  'Running time',
#  'Screen story by',
#  'Screenplay by',
#  'Starring',
#  'Story by',
#  'Suggested by',
#  'Theme music composer',
#  'Venue',
#  'Voices of',
#  'Written by',
#  'alt_titles',
#  'imdb_link',
#  'title',
#  'url',
#  'year']

# %%
wiki_movies_df.head()
# Out:
#                                                  url  year  \
# 0  https://en.wikipedia.org/wiki/The_Adventures_o...  1990
# 1  https://en.wikipedia.org/wiki/After_Dark,_My_S...  1990
# 2   https://en.wikipedia.org/wiki/Air_America_(film)  1990
# 3    https://en.wikipedia.org/wiki/Alice_(1990_film)  1990
# 4      https://en.wikipedia.org/wiki/Almost_an_Angel  1990
#
#                                imdb_link                            title  \
# 0  https://www.imdb.com/title/tt0098987/  The Adventures of Ford Fairlane
# 1  https://www.imdb.com/title/tt0098994/             After Dark, My Sweet
# 2  https://www.imdb.com/title/tt0099005/                      Air America
# 3  https://www.imdb.com/title/tt0099012/                            Alice
# 4  https://www.imdb.com/title/tt0099018/                  Almost an Angel
#
#           Directed by                  Produced by  \
# 0        Renny Harlin   [Steve Perry, Joel Silver]
# 1         James Foley  [Ric Kidney, Robert Redlin]
# 2  Roger Spottiswoode               Daniel Melnick
# 3         Woody Allen              Robert Greenhut
# 4        John Cornell                 John Cornell
#
#                                 Screenplay by                     Story by  \
# 0  [David Arnott, James Cappe, Daniel Waters]  [David Arnott, James Cappe]
# 1                [James Foley, Robert Redlin]                          NaN
# 2                  [John Eskow, Richard Rush]                          NaN
# 3                                         NaN                          NaN
# 4                                         NaN                          NaN
#
#                                             Based on  \
# 0                        [Characters, by Rex Weiner]
# 1  [the novel, After Dark, My Sweet, by, Jim Thom...
# 2             [Air America, by, Christopher Robbins]
# 3                                                NaN
# 4                                                NaN
#
#                                             Starring         Narrated by  \
# 0  [Andrew Dice Clay, Wayne Newton, Priscilla Pre...  Andrew "Dice" Clay
# 1  [Jason Patric, Rachel Ward, Bruce Dern, George...                 NaN
# 2  [Mel Gibson, Robert Downey Jr., Nancy Travis, ...                 NaN
# 3  [Alec Baldwin, Blythe Danner, Judy Davis, Mia ...                 NaN
# 4        [Paul Hogan, Elias Koteas, Linda Kozlowski]                 NaN
#
#                   Music by  Cinematography                       Edited by  \
# 0  [Cliff Eidelman, Yello]     Oliver Wood                 Michael Tronick
# 1            Maurice Jarre    Mark Plummer                 Howard E. Smith
# 2            Charles Gross   Roger Deakins  [John Bloom, Lois Freeman-Fox]
# 3                      NaN  Carlo Di Palma                  Susan E. Morse
# 4            Maurice Jarre    Russell Boyd                    David Stiven
#
#                       Productioncompany       Distributed by  \
# 0                        Silver Pictures    20th Century Fox
# 1                        Avenue Pictures     Avenue Pictures
# 2  [Carolco Pictures, IndieProd Company]    TriStar Pictures
# 3                                    NaN      Orion Pictures
# 4                                    NaN  Paramount Pictures
#
#                                         Release date Running time  \
# 0                  [July 11, 1990, (, 1990-07-11, )]  102 minutes
# 1  [May 17, 1990, (, 1990-05-17, ), (Cannes Film ...  114 minutes
# 2                [August 10, 1990, (, 1990-08-10, )]  113 minutes
# 3              [December 25, 1990, (, 1990-12-25, )]  106 minutes
# 4                                  December 19, 1990   95 minutes
#
#          Country        Language       Budget        Box office   Written by  \
# 0  United States         English  $20 million     $21.4 million          NaN
# 1  United States         English   $6 million      $2.7 million          NaN
# 2  United States  [English, Lao]  $35 million       $57,718,089          NaN
# 3  United States         English  $12 million        $7,331,647  Woody Allen
# 4             US         English  $25 million  $6,939,946 (USA)   Paul Hogan
#
#   Genre Theme music composer Country of origin Original language(s)  \
# 0   NaN                  NaN               NaN                  NaN
# 1   NaN                  NaN               NaN                  NaN
# 2   NaN                  NaN               NaN                  NaN
# 3   NaN                  NaN               NaN                  NaN
# 4   NaN                  NaN               NaN                  NaN
#
#   Producer(s) Editor(s) Production company(s) Original network  \
# 0         NaN       NaN                   NaN              NaN
# 1         NaN       NaN                   NaN              NaN
# 2         NaN       NaN                   NaN              NaN
# 3         NaN       NaN                   NaN              NaN
# 4         NaN       NaN                   NaN              NaN
#
#   Original release Productioncompanies  Executive producer(s)  \
# 0              NaN                  NaN                   NaN
# 1              NaN                  NaN                   NaN
# 2              NaN                  NaN                   NaN
# 3              NaN                  NaN                   NaN
# 4              NaN                  NaN                   NaN
#
#   Production location(s) Distributor Picture format Audio format Voices of  \
# 0                    NaN         NaN            NaN          NaN       NaN
# 1                    NaN         NaN            NaN          NaN       NaN
# 2                    NaN         NaN            NaN          NaN       NaN
# 3                    NaN         NaN            NaN          NaN       NaN
# 4                    NaN         NaN            NaN          NaN       NaN
#
#   Followed by Composer(s) Created by Preceded by Adaptation by Suggested by  \
# 0         NaN         NaN        NaN         NaN           NaN          NaN
# 1         NaN         NaN        NaN         NaN           NaN          NaN
# 2         NaN         NaN        NaN         NaN           NaN          NaN
# 3         NaN         NaN        NaN         NaN           NaN          NaN
# 4         NaN         NaN        NaN         NaN           NaN          NaN
#
#   alt_titles Released Recorded Venue Length Label Director Producer  \
# 0        NaN      NaN      NaN   NaN    NaN   NaN      NaN      NaN
# 1        NaN      NaN      NaN   NaN    NaN   NaN      NaN      NaN
# 2        NaN      NaN      NaN   NaN    NaN   NaN      NaN      NaN
# 3        NaN      NaN      NaN   NaN    NaN   NaN      NaN      NaN
# 4        NaN      NaN      NaN   NaN    NaN   NaN      NaN      NaN
#
#   Animation by Color process Screen story by
# 0          NaN           NaN             NaN
# 1          NaN           NaN             NaN
# 2          NaN           NaN             NaN
# 3          NaN           NaN             NaN
# 4          NaN           NaN             NaN

# %%
wiki_movies_df[wiki_movies_df['alt_titles'].notnull()]
# Out:
#                                                     url  year  \
# 858   https://en.wikipedia.org/wiki/The_Wedding_Banquet  1993
# 1342  https://en.wikipedia.org/wiki/Night_Watch_(199...  1995
# 1534  https://en.wikipedia.org/wiki/East_Palace,_Wes...  1996
# 1888    https://en.wikipedia.org/wiki/The_Fifth_Element  1997
# 3413  https://en.wikipedia.org/wiki/Wonderful_Days_(...  2003
# 4238           https://en.wikipedia.org/wiki/Shark_Bait  2006
# 4790    https://en.wikipedia.org/wiki/Waltz_with_Bashir  2008
# 6393  https://en.wikipedia.org/wiki/When_Marnie_Was_...  2015
# 6456             https://en.wikipedia.org/wiki/Ip_Man_3  2016
# 6613  https://en.wikipedia.org/wiki/The_Great_Wall_(...  2017
# 6620             https://en.wikipedia.org/wiki/Rock_Dog  2017
# 6661        https://en.wikipedia.org/wiki/Born_in_China  2017
# 6719       https://en.wikipedia.org/wiki/Menashe_(film)  2017
# 6829  https://en.wikipedia.org/wiki/Mary_and_the_Wit...  2018
# 6834    https://en.wikipedia.org/wiki/The_Insult_(film)  2018
# 6849      https://en.wikipedia.org/wiki/Loveless_(film)  2018
# 6862  https://en.wikipedia.org/wiki/Foxtrot_(2017_film)  2018
# 7009  https://en.wikipedia.org/wiki/My_Hero_Academia...  2018
# 7054          https://en.wikipedia.org/wiki/Shoplifters  2018
# 7058     https://en.wikipedia.org/wiki/Capernaum_(film)  2018
# 7070  https://en.wikipedia.org/wiki/Cold_War_(2018_f...  2018
#
#                                   imdb_link  \
# 858   https://www.imdb.com/title/tt0107156/
# 1342  https://www.imdb.com/title/tt0113984/
# 1534  https://www.imdb.com/title/tt0119007/
# 1888  https://www.imdb.com/title/tt0119116/
# 3413  https://www.imdb.com/title/tt0353014/
# 4238  https://www.imdb.com/title/tt0820142/
# 4790  https://www.imdb.com/title/tt1185616/
# 6393  https://www.imdb.com/title/tt3398268/
# 6456  https://www.imdb.com/title/tt2888046/
# 6613  https://www.imdb.com/title/tt2034800/
# 6620  https://www.imdb.com/title/tt2822672/
# 6661  https://www.imdb.com/title/tt4629266/
# 6719  https://www.imdb.com/title/tt6333086/
# 6829  https://www.imdb.com/title/tt6336356/
# 6834  https://www.imdb.com/title/tt7048622/
# 6849  https://www.imdb.com/title/tt6304162/
# 6862  https://www.imdb.com/title/tt6896536/
# 7009  https://www.imdb.com/title/tt7745068/
# 7054  https://www.imdb.com/title/tt8075192/
# 7058  https://www.imdb.com/title/tt8267604/
# 7070  https://www.imdb.com/title/tt6543652/
#
#                                        title                      Directed by  \
# 858                      The Wedding Banquet                          Ang Lee
# 1342                              Nightwatch                    David Jackson
# 1534                East Palace, West Palace                       Zhang Yuan
# 1888                       The Fifth Element                       Luc Besson
# 3413                          Wonderful Days                   Kim Moon-saeng
# 4238  Shark Bait (AKA: The Reef: Shark Bait)      [Howard E. Baker, John Fox]
# 4790                       Waltz with Bashir                       Ari Folman
# 6393                   When Marnie Was There             Hiromasa Yonebayashi
# 6456                                Ip Man 3                       Wilson Yip
# 6613                          The Great Wall                      Zhang Yimou
# 6620                                Rock Dog                      Ash Brannon
# 6661                           Born in China                         Lu Chuan
# 6719                                 Menashe  [Joshua Z. Weinstein, [, yi, ]]
# 6829             Mary and The Witch's Flower             Hiromasa Yonebayashi
# 6834                              The Insult                     Ziad Doueiri
# 6849                                Loveless               Andrey Zvyagintsev
# 6862                                 Foxtrot                      Samuel Maoz
# 7009            My Hero Academia: Two Heroes                   Kenji Nagasaki
# 7054                             Shoplifters                Hirokazu Kore-eda
# 7058                               Capernaum                    Nadine Labaki
# 7070                                Cold War                Paweł Pawlikowski
#
#                                             Produced by  \
# 858                  [Ang Lee, Ted Hope, James Schamus]
# 1342                                                NaN
# 1534  [Christophe Jung, Christophe Ménager, Zhang Yu...
# 1888                                     Patrice Ledoux
# 3413                      [Hwang K. S., Kyeong Hag Lee]
# 4238                                                NaN
# 4790  [Ari Folman, Serge Lalou, Gerhard Meixner, Yae...
# 6393                                 Yoshiaki Nishimura
# 6456                                       Raymond Wong
# 6613  [Thomas Tull, Charles Roven, Jon Jashni, Peter...
# 6620  [Amber Wang, David B. Miller, Rob Feng, Joyce ...
# 6661             [Roy Conli, Brian Leith, Phil Chapman]
# 6719  [Alex Lipschultz, Traci Carlson, Joshua Z. Wei...
# 6829                                 Yoshiaki Nishimura
# 6834  [Rachid Bouchareb, Jean Bréhat, Julie Gayet, A...
# 6849  [Alexander Rodnyansky, Sergey Melkumov, Gleb F...
# 6862                          [Eitan Mansuri, [, he, ]]
# 7009  [Yoshihiro Oyabu, Koji Nagai, Wakana Okamura, ...
# 7054    [Matsuzaki Kaoru, Yose Akihiko, Taguchi Hijiri]
# 7058                    [Michel Merkt, Khaled Mouzanar]
# 7070               [Tanya Seghatchian, Ewa Puszczyńska]
#
#                                           Screenplay by  \
# 858                                                 NaN
# 1342                                                NaN
# 1534                                                NaN
# 1888                    [Luc Besson, Robert Mark Kamen]
# 3413                                                NaN
# 4238                                                NaN
# 4790                                                NaN
# 6393   [Masashi Andō, Keiko Niwa, Hiromasa Yonebayashi]
# 6456                                                NaN
# 6613            [Carlo Bernard, Doug Miro, Tony Gilroy]
# 6620                        [Ash Brannon, Kurt Voelker]
# 6661  [David Fowler, Brian Leith, Phil Chapman, Lu C...
# 6719                                                NaN
# 6829             [Riko Sakaguchi, Hiromasa Yonebayashi]
# 6834                                                NaN
# 6849                   [Oleg Negin, Andrey Zvyagintsev]
# 6862                                                NaN
# 7009                                                NaN
# 7054                                                NaN
# 7058  [Nadine Labaki, Jihad Hojaily, Michelle Keserw...
# 7070                                                NaN
#
#                                                Story by  \
# 858                                                 NaN
# 1342                                                NaN
# 1534                                                NaN
# 1888                                         Luc Besson
# 3413                                                NaN
# 4238                                                NaN
# 4790                                                NaN
# 6393                                                NaN
# 6456                                                NaN
# 6613    [Max Brooks, Edward Zwick, Marshall Herskovitz]
# 6620                           [Ash Brannon, Zheng Jun]
# 6661                                                NaN
# 6719                                                NaN
# 6829                                                NaN
# 6834                                                NaN
# 6849                                                NaN
# 6862                                                NaN
# 7009                                                NaN
# 7054                                                NaN
# 7058  [Georges Khabbaz, Nadine Labaki, Michelle Kese...
# 7070                                                NaN
#
#                                             Based on  \
# 858                                              NaN
# 1342                                             NaN
# 1534                                             NaN
# 1888                                             NaN
# 3413                                             NaN
# 4238                                             NaN
# 4790                                             NaN
# 6393   [When Marnie Was There, by, Joan G. Robinson]
# 6456                                             NaN
# 6613                                             NaN
# 6620                [Tibetan Rock Dog, by Zheng Jun]
# 6661                                             NaN
# 6719                                             NaN
# 6829  [The Little Broomstick, by, Mary Stewart, [1]]
# 6834                                             NaN
# 6849                                             NaN
# 6862                                             NaN
# 7009         [My Hero Academia, by, Kōhei Horikoshi]
# 7054                                             NaN
# 7058                                             NaN
# 7070                                             NaN
#
#                                                Starring  \
# 858   [Ah-Leh Gua, Sihung Lung, May Chin, Winston Ch...
# 1342                [Pierce Brosnan, ,, Alexandra Paul]
# 1534                         [Si Han, Hu Jun, Zhao Wei]
# 1888  [Bruce Willis, Gary Oldman, Ian Holm, Chris Tu...
# 3413  [Korean, Ji Hoon Choi, Yeong Seon Eun, In Seon...
# 4238  [Freddie Prinze, Jr., Evan Rachel Wood, Donal ...
# 4790                                         Ari Folman
# 6393                   [Sara Takatsuki, Kasumi Arimura]
# 6456  [Donnie Yen, Zhang Jin, Lynn Hung, Patrick Tam...
# 6613  [Matt Damon, Jing Tian, Pedro Pascal, Willem D...
# 6620  [Luke Wilson, Eddie Izzard, J. K. Simmons, Lew...
# 6661                                                NaN
# 6719  [Menashe Lustig, [, yi, ], Ruben Niborski, Yoe...
# 6829       [Hana Sugisaki, Yūki Amami, Fumiyo Kohinata]
# 6834                       [Adel Karam, Kamel El Basha]
# 6849  [Maryana Spivak, Aleksey Rozin, Matvey Novikov...
# 6862                      [Lior Ashkenazi, Sarah Adler]
# 7009                                                NaN
# 7054  [Lily Franky, Sakura Ando, Mayu Matsuoka, Kair...
# 7058  [Zain Al Rafeea, Yordanos Shiferaw, Boluwatife...
# 7070  [Joanna Kulig, Tomasz Kot, Borys Szyc, Agata K...
#
#                                             Narrated by  \
# 858                                                 NaN
# 1342                                                NaN
# 1534                                                NaN
# 1888                                                NaN
# 3413                                                NaN
# 4238                                                NaN
# 4790                                                NaN
# 6393                                                NaN
# 6456                                                NaN
# 6613                                                NaN
# 6620                                                NaN
# 6661  [John Krasinski, (American release), Zhou Xun,...
# 6719                                                NaN
# 6829                                                NaN
# 6834                                                NaN
# 6849                                                NaN
# 6862                                                NaN
# 7009                                                NaN
# 7054                                                NaN
# 7058                                                NaN
# 7070                                                NaN
#
#                                   Music by                     Cinematography  \
# 858                                  Mader                           Jong Lin
# 1342                                   NaN                     Michael Negrin
# 1534                             Xiang Min                         Zhang Jian
# 1888                            Éric Serra                   Thierry Arbogast
# 3413                                Won II                                NaN
# 4238                  Christopher Lennertz                                NaN
# 4790                           Max Richter                                NaN
# 6393                   Takatsugu Muramatsu                       Atsushi Okuo
# 6456                           Kenji Kawai                          Kenny Tse
# 6613                         Ramin Djawadi   [Stuart Dryburgh, Zhao Xiaoding]
# 6620                            Rolfe Kent                                NaN
# 6661                        Barnaby Taylor                                NaN
# 6719        [Aaron Martin, Dag Rosenqvist]  [Yoni Brook, Joshua Z. Weinstein]
# 6829                   Takatsugu Muramatsu                       Toru Fukushi
# 6834                           Éric Neveux                   Tommaso Fiorilli
# 6849  [Evgueni Galperine, Sacha Galperine]                   Mikhail Krichman
# 6862     [Ophir Leibovitch, Amit Poznanky]                       Giora Bejach
# 7009                          Yuki Hayashi                                NaN
# 7054                        Haruomi Hosono                        Kondo Ryuto
# 7058                       Khaled Mouzanar                   Christopher Aoun
# 7070                                   NaN                         Łukasz Żal
#
#                                          Edited by  \
# 858                                    Tim Squyres
# 1342                                           NaN
# 1534                                  Vincent Lévy
# 1888                                 Sylvie Landra
# 3413                                           NaN
# 4238                                   Tom Sanders
# 4790                                   Nili Feller
# 6393                                 Rie Matsubara
# 6456                                 Cheung Ka-fai
# 6613                  [Mary Jo Markey, Craig Wood]
# 6620                    [Ivan Bilancio, Ed Fuller]
# 6661                                 Matthew Meech
# 6719                                Scott Cummings
# 6829                                           NaN
# 6834                            Dominique Marcombe
# 6849                                     Anna Mass
# 6862  [Arik Lahav Leibovich, [, he, ], Guy Nemesh]
# 7009                                           NaN
# 7054                             Hirokazu Kore-eda
# 7058                               Konstantin Bock
# 7070                             Jaroslaw Kaminski
#
#                                      Productioncompany   \
# 858                                        Good Machine
# 1342                                                NaN
# 1534                                                NaN
# 1888                       [Columbia Pictures, Gaumont]
# 3413  [Endgame Productions Inc., Masquerade Films, M...
# 4238                                                NaN
# 4790                                                NaN
# 6393                                      Studio Ghibli
# 6456                                                NaN
# 6613  [Legendary East, Atlas Entertainment, [1], Chi...
# 6620                                                NaN
# 6661  [Disneynature, Shanghai Media Group, Chuan Fil...
# 6719                                                NaN
# 6829          [Studio Ponoc, Nippon Television Network]
# 6834  [Ezekiel Films, Tessalit Productions, Rouge In...
# 6849          [Arte France Cinéma, Why Not Productions]
# 6862                                   Bord Cadre Films
# 7009                                              Bones
# 7054                                      Aoi Pro, Inc.
# 7058                                         Mooz Films
# 7070  [Opus Film, Polish Film Institute, MK2 Films, ...
#
#                                          Distributed by  \
# 858                          The Samuel Goldwyn Company
# 1342                                                NaN
# 1534                                   Fortissimo Films
# 1888  [Gaumont Buena Vista International, [1], (Fran...
# 3413  [Palisades Tartan, (English releases), Gainax,...
# 4238                                   CJ Entertainment
# 4790                             Sony Pictures Classics
# 6393                                               Toho
# 6456                            Pegasus Motion Pictures
# 6613  [Universal Pictures, (US/international), [2], ...
# 6620  [Huayi Brothers, (China), Summit Premiere, (Un...
# 6661  [Walt Disney Studios, Motion Pictures, Shangha...
# 6719                                                A24
# 6829                                               Toho
# 6834  [Diaphana Films, (France), Italia Film, (Lebanon]
# 6849           [Sony Pictures Releasing, (Russia), [1]]
# 6862                                                NaN
# 7009                                               Toho
# 7054                                      GAGA Pictures
# 7058                             Sony Pictures Classics
# 7070  [Kino Świat (Poland), Diaphana Films (France),...
#
#                                            Release date  \
# 858   [4 August 1993, (, 1993-08-04, ), (United Stat...
# 1342                                                NaN
# 1534  [November 1996, (, 1996-11, ), (, Mar del Plat...
# 1888                     [7 May 1997, (, 1997-05-07, )]
# 3413                  [July 17, 2003, (, 2003-07-17, )]
# 4238    [July 7, 2006, (, 2006-07-07, ), (South Korea)]
# 4790  [13 May 2008, (, 2008-05-13, ), (, Cannes, ), ...
# 6393                   [19 July 2014, (, 2014-07-19, )]
# 6456  [16 December 2015, (, 2015-12-16, ), (Hong Kon...
# 6613  [December 6, 2016, (, 2016-12-06, ), (, Beijin...
# 6620  [June 2016, (, 2016-06, ), (, SIFF, ), [2], Ju...
# 6661  [August 12, 2016, (, 2016-08-12, ), (China), A...
# 6719  [January 23, 2017, (, 2017-01-23, ), (, Sundan...
# 6829                    [8 July 2017, (, 2017-07-08, )]
# 6834  [31 August 2017, (, 2017-08-31, ), (, Venice, ...
# 6849  [18 May 2017, (, 2017-05-18, ), (, Cannes, ), ...
# 6862  [2 September 2017, (, 2017-09-02, ), (, Venice...
# 7009  [July 5, 2018, (, 2018-07-05, ), (, Anime Expo...
# 7054  [13 May 2018, (, 2018-05-13, ), (, Cannes, ), ...
# 7058  [17 May 2018, (, 2018-05-17, ), (, Cannes, ), ...
# 7070  [10 May 2018, (, 2018-05-10, ), (, Cannes, ), ...
#
#                                            Running time  \
# 858                                         106 minutes
# 1342                                        101 minutes
# 1534                                         94 minutes
# 1888                                        126 minutes
# 3413  [86 Min, (Original Release), 95 Min, (Director...
# 4238                                         77 minutes
# 4790                                         90 minutes
# 6393                                        103 minutes
# 6456                                        105 minutes
# 6613                                        103 minutes
# 6620                                         80 minutes
# 6661                                         76 minutes
# 6719                                         81 minutes
# 6829                                        103 minutes
# 6834                                        112 minutes
# 6849                                        127 minutes
# 6862                                        112 minutes
# 7009                                         96 minutes
# 7054                                        121 minutes
# 7058                                        126 minutes
# 7070                                         88 minutes
#
#                                           Country  \
# 858                       [Taiwan, United States]
# 1342                                          NaN
# 1534                                        China
# 1888                                       France
# 3413                                  South Korea
# 4238                 [United States, South Korea]
# 4790                    [Israel, Germany, France]
# 6393                                        Japan
# 6456                                    Hong Kong
# 6613             [United States, [5], China, [5]]
# 6620                       [China, United States]
# 6661                       [United States, China]
# 6719                                United States
# 6829                                        Japan
# 6834                            [France, Lebanon]
# 6849      [Russia, France, Belgium, Germany, [3]]
# 6862  [Israel, Germany, France, Switzerland, [3]]
# 7009                                        Japan
# 7054                                        Japan
# 7058                                      Lebanon
# 7070             [Poland, France, United Kingdom]
#
#                          Language                                  Budget  \
# 858   [Mandarin Chinese, English]                              $1 million
# 1342                          NaN                              $6,000,000
# 1534                     Mandarin                                     NaN
# 1888                      English  [$90 million, [4], [5], [6], [7], [a]]
# 3413            [Korean, English]                                     NaN
# 4238                      English                             $10 million
# 4790                       Hebrew                              $2 million
# 6393                     Japanese    [¥1.15 billion, (, $10.5 million, )]
# 6456                    Cantonese                  [US$, 36 million, [3]]
# 6613          [English, Mandarin]                            $150 million
# 6620           [Chinese, English]                             $60 million
# 6661          [English, Mandarin]                           $5–10 million
# 6719           [Yiddish, English]                                     NaN
# 6829                     Japanese                                     NaN
# 6834              Lebanese Arabic                                     NaN
# 6849                      Russian                                     NaN
# 6862                       Hebrew                                     NaN
# 7009                     Japanese                                     NaN
# 7054                     Japanese                                     NaN
# 7058            [Arabic, Amharic]                              $4 million
# 7070             [Polish, French]                            €4.3 million
#
#                               Box office  \
# 858                        $23.6 million
# 1342                                 NaN
# 1534                                 NaN
# 1888                      $263.9 million
# 3413                                 NaN
# 4238                       $13.7 million
# 4790                         $11,125,849
# 6393  [¥3.85 billion, (, $36 million, )]
# 6456                        $157,300,954
# 6613                      $334.9 million
# 6620                       $24.1 million
# 6661                       $25.1 million
# 6719                        $1.7 million
# 6829                [$, 41 million, [3]]
# 6834                        $1.6 million
# 6849                        $4.8 million
# 6862                            $497,096
# 7009                         $27,844,607
# 7054                       $72.7 million
# 7058                       $68.6 million
# 7070                       $19.4 million
#
#                                              Written by               Genre  \
# 858                 [Ang Lee, Neil Peng, James Schamus]                 NaN
# 1342  [Alistair MacLean, (story),, Alistair MacNeill...  [Action, Thriller]
# 1534                          [Wang Xiaobo, Zhang Yuan]                 NaN
# 1888                                                NaN                 NaN
# 3413                    [Kim Moon-saeng, Park Jun-Yong]                 NaN
# 4238  [Scott Clevenger, Chris Denk, Anurag Mehta, Ti...                 NaN
# 4790                                         Ari Folman                 NaN
# 6393                                                NaN                 NaN
# 6456             [Edmond Wong, Chan Tai-lee, Jil Leung]                 NaN
# 6613                                                NaN                 NaN
# 6620                                                NaN                 NaN
# 6661                                                NaN                 NaN
# 6719  [Alex Lipschultz, Musa Syeed, Joshua Z. Weinst...                 NaN
# 6829                                                NaN                 NaN
# 6834                       [Ziad Doueiri, Joelle Touma]                 NaN
# 6849                                                NaN                 NaN
# 6862                                        Samuel Maoz                 NaN
# 7009                                      Yōsuke Kuroda                 NaN
# 7054                                  Hirokazu Kore-eda                 NaN
# 7058                                                NaN                 NaN
# 7070  [Paweł Pawlikowski, Janusz Głowacki, Piotr Bor...                 NaN
#
#      Theme music composer Country of origin Original language(s)  \
# 858                   NaN               NaN                  NaN
# 1342           John Scott     United States              English
# 1534                  NaN               NaN                  NaN
# 1888                  NaN               NaN                  NaN
# 3413                  NaN               NaN                  NaN
# 4238                  NaN               NaN                  NaN
# 4790                  NaN               NaN                  NaN
# 6393                  NaN               NaN                  NaN
# 6456                  NaN               NaN                  NaN
# 6613                  NaN               NaN                  NaN
# 6620                  NaN               NaN                  NaN
# 6661                  NaN               NaN                  NaN
# 6719                  NaN               NaN                  NaN
# 6829                  NaN               NaN                  NaN
# 6834                  NaN               NaN                  NaN
# 6849                  NaN               NaN                  NaN
# 6862                  NaN               NaN                  NaN
# 7009                  NaN               NaN                  NaN
# 7054                  NaN               NaN                  NaN
# 7058                  NaN               NaN                  NaN
# 7070                  NaN               NaN                  NaN
#
#                                             Producer(s)          Editor(s)  \
# 858                                                 NaN                NaN
# 1342  [Boris Dmitrovic, (line producer), Mike Mihali...  Eric Boyd-Perkins
# 1534                                                NaN                NaN
# 1888                                                NaN                NaN
# 3413                                                NaN                NaN
# 4238                                                NaN                NaN
# 4790                                                NaN                NaN
# 6393                                                NaN                NaN
# 6456                                                NaN                NaN
# 6613                                                NaN                NaN
# 6620                                                NaN                NaN
# 6661                                                NaN                NaN
# 6719                                                NaN                NaN
# 6829                                                NaN                NaN
# 6834                                                NaN                NaN
# 6849                                                NaN                NaN
# 6862                                                NaN                NaN
# 7009                                                NaN                NaN
# 7054                                                NaN                NaN
# 7058                                                NaN                NaN
# 7070                                                NaN                NaN
#
#      Production company(s) Original network  \
# 858                    NaN              NaN
# 1342     J&M Entertainment              USA
# 1534                   NaN              NaN
# 1888                   NaN              NaN
# 3413                   NaN              NaN
# 4238                   NaN              NaN
# 4790                   NaN              NaN
# 6393                   NaN              NaN
# 6456                   NaN              NaN
# 6613                   NaN              NaN
# 6620                   NaN              NaN
# 6661                   NaN              NaN
# 6719                   NaN              NaN
# 6829                   NaN              NaN
# 6834                   NaN              NaN
# 6849                   NaN              NaN
# 6862                   NaN              NaN
# 7009                   NaN              NaN
# 7054                   NaN              NaN
# 7058                   NaN              NaN
# 7070                   NaN              NaN
#
#                           Original release  \
# 858                                    NaN
# 1342  [October 13, 1995, (, 1995-10-13, )]
# 1534                                   NaN
# 1888                                   NaN
# 3413                                   NaN
# 4238                                   NaN
# 4790                                   NaN
# 6393                                   NaN
# 6456                                   NaN
# 6613                                   NaN
# 6620                                   NaN
# 6661                                   NaN
# 6719                                   NaN
# 6829                                   NaN
# 6834                                   NaN
# 6849                                   NaN
# 6862                                   NaN
# 7009                                   NaN
# 7054                                   NaN
# 7058                                   NaN
# 7070                                   NaN
#
#                                    Productioncompanies  Executive producer(s)  \
# 858                                                 NaN                   NaN
# 1342                                                NaN                   NaN
# 1534                                                NaN                   NaN
# 1888                                                NaN                   NaN
# 3413                                                NaN                   NaN
# 4238                                                NaN                   NaN
# 4790  [Bridgit Folman Film Gang, Les Films d'Ici, Ra...                   NaN
# 6393                                                NaN                   NaN
# 6456  [Dreams Salon Entertainment Culture, Pegasus M...                   NaN
# 6613                                                NaN                   NaN
# 6620  [Mandoo Pictures, Huayi Tencent Entertainment ...                   NaN
# 6661                                                NaN                   NaN
# 6719                                                NaN                   NaN
# 6829                                                NaN                   NaN
# 6834                                                NaN                   NaN
# 6849                                                NaN                   NaN
# 6862                                                NaN                   NaN
# 7009                                                NaN                   NaN
# 7054                                                NaN                   NaN
# 7058                                                NaN                   NaN
# 7070                                                NaN                   NaN
#
#      Production location(s)  Distributor Picture format Audio format  \
# 858                     NaN          NaN            NaN          NaN
# 1342                    NaN  USA Network          Color       Stereo
# 1534                    NaN          NaN            NaN          NaN
# 1888                    NaN          NaN            NaN          NaN
# 3413                    NaN          NaN            NaN          NaN
# 4238                    NaN          NaN            NaN          NaN
# 4790                    NaN          NaN            NaN          NaN
# 6393                    NaN          NaN            NaN          NaN
# 6456                    NaN          NaN            NaN          NaN
# 6613                    NaN          NaN            NaN          NaN
# 6620                    NaN          NaN            NaN          NaN
# 6661                    NaN          NaN            NaN          NaN
# 6719                    NaN          NaN            NaN          NaN
# 6829                    NaN          NaN            NaN          NaN
# 6834                    NaN          NaN            NaN          NaN
# 6849                    NaN          NaN            NaN          NaN
# 6862                    NaN          NaN            NaN          NaN
# 7009                    NaN          NaN            NaN          NaN
# 7054                    NaN          NaN            NaN          NaN
# 7058                    NaN          NaN            NaN          NaN
# 7070                    NaN          NaN            NaN          NaN
#
#      Voices of Followed by Composer(s) Created by Preceded by Adaptation by  \
# 858        NaN         NaN         NaN        NaN         NaN           NaN
# 1342       NaN         NaN         NaN        NaN         NaN           NaN
# 1534       NaN         NaN         NaN        NaN         NaN           NaN
# 1888       NaN         NaN         NaN        NaN         NaN           NaN
# 3413       NaN         NaN         NaN        NaN         NaN           NaN
# 4238       NaN         NaN         NaN        NaN         NaN           NaN
# 4790       NaN         NaN         NaN        NaN         NaN           NaN
# 6393       NaN         NaN         NaN        NaN         NaN           NaN
# 6456       NaN         NaN         NaN        NaN         NaN           NaN
# 6613       NaN         NaN         NaN        NaN         NaN           NaN
# 6620       NaN         NaN         NaN        NaN         NaN           NaN
# 6661       NaN         NaN         NaN        NaN         NaN           NaN
# 6719       NaN         NaN         NaN        NaN         NaN           NaN
# 6829       NaN         NaN         NaN        NaN         NaN           NaN
# 6834       NaN         NaN         NaN        NaN         NaN           NaN
# 6849       NaN         NaN         NaN        NaN         NaN           NaN
# 6862       NaN         NaN         NaN        NaN         NaN           NaN
# 7009       NaN         NaN         NaN        NaN         NaN           NaN
# 7054       NaN         NaN         NaN        NaN         NaN           NaN
# 7058       NaN         NaN         NaN        NaN         NaN           NaN
# 7070       NaN         NaN         NaN        NaN         NaN           NaN
#
#      Suggested by                                         alt_titles Released  \
# 858           NaN         {'Mandarin': 'Xǐyàn', 'Traditional': '喜宴'}      NaN
# 1342          NaN     {'Also known as': 'Detonator II: Night Watch'}      NaN
# 1534          NaN  {'Mandarin': 'Dōng Gōng Xī Gōng', 'Simplified'...      NaN
# 1888          NaN                 {'French': 'Le Cinquième Élément'}      NaN
# 3413          NaN  {'Hangul': '원더풀 데이즈', 'McCune–Reischauer': 'Wŏ...      NaN
# 4238          NaN  {'Hangul': '파이 스토리', 'McCune–Reischauer': 'P‘a...      NaN
# 4790          NaN                {'Original title': 'ואלס עם באשיר'}      NaN
# 6393          NaN  {'Hepburn': 'Omoide no Mānī', 'Japanese': '思い出...      NaN
# 6456          NaN  {'Cantonese': ['Jip', '6', 'Man', '6', 'Saam',...      NaN
# 6613          NaN  {'Mandarin': 'Cháng Chéng', 'Simplified': '长城'...      NaN
# 6620          NaN                                {'Chinese': '摇滚藏獒'}      NaN
# 6661          NaN  {'Simplified': '我们诞生在中国', 'Traditional': '我們誕生...      NaN
# 6719          NaN                                {'Yiddish': 'מנשה'}      NaN
# 6829          NaN  {'Hepburn': 'Meari to Majo no Hana', 'Japanese...      NaN
# 6834          NaN  {'Arabic': 'قضية رقم ٢٣', 'Literally': 'Case N...      NaN
# 6849          NaN   {'Romanized': 'Nelyubov', 'Russian': 'Нелюбовь'}      NaN
# 6862          NaN                         {'Hebrew': 'פוֹקְסטְרוֹט'}      NaN
# 7009          NaN  {'Hepburn': 'Boku no Hīrō Akademia THE MOVIE: ...      NaN
# 7054          NaN  {'Hepburn': 'Manbiki Kazoku', 'Japanese': '万引き...      NaN
# 7058          NaN                            {'Arabic': 'کفرناحوم‎'}      NaN
# 7070          NaN                          {'Polish': 'Zimna wojna'}      NaN
#
#      Recorded Venue Length Label Director Producer Animation by Color process  \
# 858       NaN   NaN    NaN   NaN      NaN      NaN          NaN           NaN
# 1342      NaN   NaN    NaN   NaN      NaN      NaN          NaN           NaN
# 1534      NaN   NaN    NaN   NaN      NaN      NaN          NaN           NaN
# 1888      NaN   NaN    NaN   NaN      NaN      NaN          NaN           NaN
# 3413      NaN   NaN    NaN   NaN      NaN      NaN          NaN           NaN
# 4238      NaN   NaN    NaN   NaN      NaN      NaN          NaN           NaN
# 4790      NaN   NaN    NaN   NaN      NaN      NaN          NaN           NaN
# 6393      NaN   NaN    NaN   NaN      NaN      NaN          NaN           NaN
# 6456      NaN   NaN    NaN   NaN      NaN      NaN          NaN           NaN
# 6613      NaN   NaN    NaN   NaN      NaN      NaN          NaN           NaN
# 6620      NaN   NaN    NaN   NaN      NaN      NaN          NaN           NaN
# 6661      NaN   NaN    NaN   NaN      NaN      NaN          NaN           NaN
# 6719      NaN   NaN    NaN   NaN      NaN      NaN          NaN           NaN
# 6829      NaN   NaN    NaN   NaN      NaN      NaN          NaN           NaN
# 6834      NaN   NaN    NaN   NaN      NaN      NaN          NaN           NaN
# 6849      NaN   NaN    NaN   NaN      NaN      NaN          NaN           NaN
# 6862      NaN   NaN    NaN   NaN      NaN      NaN          NaN           NaN
# 7009      NaN   NaN    NaN   NaN      NaN      NaN          NaN           NaN
# 7054      NaN   NaN    NaN   NaN      NaN      NaN          NaN           NaN
# 7058      NaN   NaN    NaN   NaN      NaN      NaN          NaN           NaN
# 7070      NaN   NaN    NaN   NaN      NaN      NaN          NaN           NaN
#
#      Screen story by
# 858              NaN
# 1342             NaN
# 1534             NaN
# 1888             NaN
# 3413             NaN
# 4238             NaN
# 4790             NaN
# 6393             NaN
# 6456             NaN
# 6613             NaN
# 6620             NaN
# 6661             NaN
# 6719             NaN
# 6829             NaN
# 6834             NaN
# 6849             NaN
# 6862             NaN
# 7009             NaN
# 7054             NaN
# 7058             NaN
# 7070             NaN
